# %% [markdown]
# # 训练的提速
# 实际训练后发现，速度没有预想得那么快，打开GPU性能窗口发现大多数时间GPU只是显存占用，算力占用为0,而CPU确实占满了的。
# [GPU](../images/GPU.png)，经过测试和查阅资料，发现是因为CPU的读取速度过慢导致跟不上GPU的运算，进而使得大部分时间都是消耗在CPU调用数据，GPU都是闲置的，如果只有我的电脑这样倒也没啥，可能说明我的CPU比较垃圾，但是在kaggle上的测试也是这样[kaggle](../images/kaggle.png)，进一步查阅资料和测试发现，合理设置num_workers可以缓解这一问题，不同num_workers的耗时对比见下图[time_consume_w.png](../images/time_consume_w.png),可以看到，训练的时间基本都是稳定的，占比很小，占大头的都是进入和退出for循环和epoch，这个都是CPU读取数据的耗时，下面测试各种优化方法，看看哪种有效。

# %% [markdown]
# ## 1.设置不同的num_workers
#
# 设置不同的num_workers确实可以影响，但是其他参数变了之后这个好像也要重新选，在batch_size = 32的情况下，测试不同batch_size的影响如下图所示：
# 在cornell上的测试结果：
#
# [time_consume_c.png](../images/time_consume_c.png)
#
# 在jacquard上的测试结果：
#
# [time_consume_j.png](../images/time_consume_j.png)

# %% [markdown]
# ## 2.使用dali库
# NVIDIA DALI（R）是NVIDIA的数据加载库，它是高度优化的构建基块和执行引擎的集合，可加速深度学习应用程序输入数据的预处理。DALI提供了性能和灵活性，可以作为一个库来加速不同的数据管道。然后可以将该库轻松集成到不同的深度学习训练和推理应用程序中。
#
# 主要就是想了利用它从磁盘批量读取图像文件并转换成Tensor文件，同时可以执行一定的增强操作。
#
# 下面按照官方的例程来试一下

# %%
from nvidia.dali.pipeline import Pipeline

help(Pipeline)
# Out:
# Help on class Pipeline in module nvidia.dali.pipeline:
#
# class Pipeline(builtins.object)
#  |  Pipeline class is the base of all DALI data pipelines. The pipeline
#  |  encapsulates the data processing graph and the execution engine.
#  |
#  |  Parameters
#  |  ----------
#  |  `batch_size` : int, optional, default = -1
#  |      Batch size of the pipeline. Negative values for this parameter
#  |      are invalid - the default value may only be used with
#  |      serialized pipeline (the value stored in serialized pipeline
#  |      is used instead).
#  |  `num_threads` : int, optional, default = -1
#  |      Number of CPU threads used by the pipeline.
#  |      Negative values for this parameter are invalid - the default
#  |      value may only be used with serialized pipeline (the value
#  |      stored in serialized pipeline is used instead).
#  |  `device_id` : int, optional, default = -1
#  |      Id of GPU used by the pipeline.
#  |      A None value for this parameter means that DALI should not use GPU nor CUDA runtime.
#  |      This limits the pipeline to only CPU operators but allows it to run on any CPU capable machine.
#  |  `seed` : int, optional, default = -1
#  |      Seed used for random number generation. Leaving the default value
#  |      for this parameter results in random seed.
#  |  `exec_pipelined` : bool, optional, default = True
#  |      Whether to execute the pipeline in a way that enables
#  |      overlapping CPU and GPU computation, typically resulting
#  |      in faster execution speed, but larger memory consumption.
#  |  `prefetch_queue_depth` : int or {"cpu_size": int, "gpu_size": int}, optional, default = 2
#  |      Depth of the executor pipeline. Deeper pipeline makes DALI
#  |      more resistant to uneven execution time of each batch, but it
#  |      also consumes more memory for internal buffers.
#  |      Specifying a dict:
#  |      ``{ "cpu_size": x, "gpu_size": y }``
#  |      instead of an integer will cause the pipeline to use separated
#  |      queues executor, with buffer queue size `x` for cpu stage
#  |      and `y` for mixed and gpu stages. It is not supported when both `exec_async`
#  |      and `exec_pipelined` are set to `False`.
#  |      Executor will buffer cpu and gpu stages separatelly,
#  |      and will fill the buffer queues when the first :meth:`run`
#  |      is issued.
#  |  `exec_async` : bool, optional, default = True
#  |      Whether to execute the pipeline asynchronously.
#  |      This makes :meth:`run` method
#  |      run asynchronously with respect to the calling Python thread.
#  |      In order to synchronize with the pipeline one needs to call
#  |      :meth:`outputs` method.
#  |  `bytes_per_sample` : int, optional, default = 0
#  |      A hint for DALI for how much memory to use for its tensors.
#  |  `set_affinity` : bool, optional, default = False
#  |      Whether to set CPU core affinity to the one closest to the
#  |      GPU being used.
#  |  `max_streams` : int, optional, default = -1
#  |      Limit the number of CUDA streams used by the executor.
#  |      Value of -1 does not impose a limit.
#  |      This parameter is currently unused (and behavior of
#  |      unrestricted number of streams is assumed).
#  |  `default_cuda_stream_priority` : int, optional, default = 0
#  |      CUDA stream priority used by DALI. See `cudaStreamCreateWithPriority` in CUDA documentation
#  |  `enable_memory_stats`: bool, optional, default = False
#  |      If DALI should print operator output buffer statistics.
#  |      Usefull for `bytes_per_sample_hint` operator parameter.
#  |
#  |  Methods defined here:
#  |
#  |  __enter__(self)
#  |      Safely sets the pipeline as current.
#  |      Current pipeline is required to call operators with side effects or without outputs.
#  |      Examples of such operators are `PythonFunction` (potential side effects) or `DumpImage`
#  |      (no output).
#  |
#  |      Any dangling operator can be marked as having side effects if it's marked
#  |      with `preserve=True`, which can be useful for debugging - otherwise operator which
#  |      does not contribute to the pipeline output is removed from the graph.
#  |
#  |      To manually set new (and restore previous) current pipeline, use :meth:`push_current`
#  |      and :meth:`pop_current`, respectively.
#  |
#  |  __exit__(self, exception_type, exception_value, traceback)
#  |      Safely restores previous pipeline.
#  |
#  |  __init__(self, batch_size=-1, num_threads=-1, device_id=-1, seed=-1, exec_pipelined=True, prefetch_queue_depth=2, exec_async=True, bytes_per_sample=0, set_affinity=False, max_streams=-1, default_cuda_stream_priority=0, *, enable_memory_stats=False)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  add_sink(self, edge)
#  |      Allows to manual add of graph edges to the pipeline which are not connected to the output and all pruned
#  |
#  |  build(self, define_graph=None)
#  |      Build the pipeline.
#  |
#  |      Pipeline needs to be built in order to run it standalone.
#  |      Framework-specific plugins handle this step automatically.
#  |
#  |      Parameters
#  |      ----------
#  |      define_graph : callable
#  |          If specified, this function will be used instead of member :meth:`define_graph`.
#  |          This parameter must not be set, if the pipeline outputs are specified with
#  |          :meth:`set_outputs`.
#  |
#  |  define_graph(self)
#  |      This function is defined by the user to construct the
#  |      graph of operations for their pipeline.
#  |
#  |      It returns a list of outputs created by calling DALI Operators.
#  |
#  |  deserialize_and_build(self, serialized_pipeline)
#  |      Deserialize and build the pipeline given in serialized form.
#  |
#  |      Parameters
#  |      ----------
#  |      serialized_pipeline : str
#  |                            Serialized pipeline.
#  |
#  |  empty(self)
#  |      If there is any work scheduled in the pipeline but not yet consumed
#  |
#  |  enable_api_check(self, enable)
#  |      Allows to enable or disable API check in the runtime
#  |
#  |  epoch_size(self, name=None)
#  |      Epoch size of a pipeline.
#  |
#  |      If the `name` parameter is `None`, returns a dictionary of pairs
#  |      `(reader name, epoch size for that reader)`.
#  |      If the `name` parameter is not `None`, returns epoch size for that
#  |      reader.
#  |
#  |      Parameters
#  |      ----------
#  |      name : str, optional, default = None
#  |          The reader which should be used to obtain epoch size.
#  |
#  |  executor_statistics(self)
#  |      Returns provided pipeline executor statistics metadata as a dictionary.
#  |      Each key in the dictionary is the operator name. To enable it use ``executor_statistics``
#  |
#  |      Available metadata keys for each operator:
#  |
#  |      ``real_memory_size``:     list of memory sizes that is used by each output of the operator;
#  |                                index in the list corresponds to the output index
#  |
#  |      ``max_real_memory_size``: list of maximum tensor size that is used by each output of the operator;
#  |                                index in the list corresponds to the output index
#  |
#  |      ``reserved_memory_size``: list of memory sizes that is reserved for each of the operator outputs
#  |                                index in the list corresponds to the output index
#  |
#  |      ``max_reserved_memory_size``: list of maximum memory sizes per tensor that is reserved for each of the operator outputs
#  |                                index in the list corresponds to the output index
#  |
#  |  feed_input(self, data_node, data, layout=None, cuda_stream=None, use_copy_kernel=False)
#  |      Pass a mutlidimensional array or DLPack (or a list thereof) to an output of ExternalSource.
#  |      In the case of the GPU input, the data must be modified on the same stream as the one
#  |      used by feed_input. See ``cuda_stream`` parameter for details.
#  |
#  |      Parameters
#  |      ----------
#  |      data_node : :class:`DataNode` or str
#  |          The name of the :class:`nvidia.dali.ops.ExternalSource` node or a :class:`DataNode`
#  |          object returned by a call to that ExternalSource.
#  |
#  |      data : an ndarray or DLPack or a list thereof
#  |          The array(s) may be one of:
#  |            * NumPy ndarray (CPU)
#  |            * MXNet ndarray (CPU)
#  |            * PyTorch tensor (CPU or GPU)
#  |            * CuPy array (GPU)
#  |            * objects implementing ``__cuda_array_interface__``
#  |            * DALI `TensorList` or list of DALI `Tensor` objects
#  |
#  |          The data to be used as the output of the ExternalSource referred to by `data_node`.
#  |
#  |      layout : str or None
#  |          The description of the data layout (or empty string, if not specified).
#  |          It should be a string of the length that matches the dimensionality of the data, batch
#  |          dimension excluded. For a batch of channel-first images, this should be "CHW", for
#  |          channel-last video it's "FHWC" and so on.
#  |          If ``data`` is a DALI `TensorList` or a list of DALI `Tensor` objects and ``layout``
#  |          is ``None``, the layout is taken from ``data``.
#  |
#  |      cuda_stream : optional, `cudaStream_t` or an object convertible to `cudaStream_t`, e.g. `cupy.cuda.Stream`, `torch.cuda.Stream`
#  |          The CUDA stream, which is going to be used for copying data to GPU or from a GPU
#  |          source. If not set, best effort will be taken to maintain correctness - i.e. if the data
#  |          is provided as a tensor/array from a recognized library (CuPy, PyTorch), the library's
#  |          current stream is used. This should work in typical scenarios, but advanced use cases
#  |          (and code using unsupported libraries) may still need to supply the stream handle
#  |          explicitly.
#  |
#  |          Special values:
#  |            *  0 - use default CUDA stream
#  |            * -1 - use DALI's internal stream
#  |
#  |          If internal stream is used, the call to ``feed_input`` will block until the copy to
#  |          internal buffer is complete, since there's no way to synchronize with this stream to
#  |          prevent overwriting the array with new data in another stream.
#  |
#  |      use_copy_kernel : optional, `bool`
#  |          If set to True, DALI will use a CUDA kernel to feed the data (only applicable when copying
#  |          data to/from GPU memory) instead of cudaMemcpyAsync (default).
#  |
#  |  iter_setup(self)
#  |      This function can be overriden by user-defined
#  |      pipeline to perform any needed setup for each iteration.
#  |      For example, one can use this function to feed the input
#  |      data from NumPy arrays.
#  |
#  |  outputs(self)
#  |      Returns the outputs of the pipeline and releases previous buffer.
#  |
#  |      If the pipeline is executed asynchronously, this function blocks
#  |      until the results become available. It rises StopIteration if data set
#  |      reached its end - usually when iter_setup cannot produce any more data.
#  |
#  |      :return:
#  |          A list of `TensorList` objects for respective pipeline outputs
#  |
#  |  reader_meta(self, name=None)
#  |      Returns provided reader metadata as a dictionary. If no name is provided if provides
#  |      a dictionary with data for all readers as {reader_name : meta}
#  |
#  |      Available metadata keys:
#  |
#  |      ``epoch_size``:        raw epoch size
#  |
#  |      ``epoch_size_padded``: epoch size with the padding at the end to be divisible by the number of shards
#  |
#  |      ``number_of_shards``:  number of shards
#  |
#  |      ``shard_id``:          shard id of given reader
#  |
#  |      ``pad_last_batch``:    if given reader should pad last batch
#  |
#  |      ``stick_to_shard``:    if given reader should stick to its shard
#  |
#  |      Parameters
#  |      ----------
#  |      name : str, optional, default = None
#  |          The reader which should be used to obtain shards_number.
#  |
#  |  release_outputs(self)
#  |      Release buffers returned by share_outputs calls.
#  |
#  |      It helps in case when output call result is consumed (copied)
#  |      and buffers can be marked as free before the next call to share_outputs. It provides
#  |      the user with better control about when he wants to run the pipeline, when he wants
#  |      to obtain the resulting buffers and when they can be returned to DALI pool when the
#  |      results have been consumed.
#  |      Needs to be used together with :meth:`schedule_run`
#  |      and :meth:`share_outputs`
#  |      Should not be mixed with :meth:`run` in the same pipeline
#  |
#  |  reset(self)
#  |      Resets pipeline iterator
#  |
#  |      If pipeline iterator reached the end then reset its state to the beginning.
#  |
#  |  run(self)
#  |      Run the pipeline and return the result.
#  |
#  |      If the pipeline was created with `exec_pipelined` option set to `True`,
#  |      this function will also start prefetching the next iteration for
#  |      faster execution.
#  |      Should not be mixed with :meth:`schedule_run` in the same pipeline,
#  |      :meth:`share_outputs` and
#  |      :meth:`release_outputs`
#  |
#  |      :return:
#  |          A list of `TensorList` objects for respective pipeline outputs
#  |
#  |  save_graph_to_dot_file(self, filename, show_tensors=False, show_ids=False, use_colors=False)
#  |      Saves the pipeline graph to a file.
#  |
#  |      Parameters
#  |      ----------
#  |      filename : str
#  |                 Name of the file to which the graph is written.
#  |      show_tensors : bool
#  |                 Show the Tensor nodes in the graph (by default only Operator nodes are shown)
#  |      show_ids : bool
#  |                 Add the node id to the graph representation
#  |      use_colors : bool
#  |                 Whether use color to distinguish stages
#  |
#  |  schedule_run(self)
#  |      Run the pipeline without returning the resulting buffers.
#  |
#  |      If the pipeline was created with `exec_pipelined` option set to `True`,
#  |      this function will also start prefetching the next iteration for
#  |      faster execution. It provides better control to the users about when they
#  |      want to run the pipeline, when they want to obtain resulting buffers
#  |      and return them to DALI buffer pool when the results have been consumed.
#  |      Needs to be used together with :meth:`release_outputs`
#  |      and :meth:`share_outputs`.
#  |      Should not be mixed with :meth:`run` in the same pipeline
#  |
#  |  serialize(self, define_graph=None, filename=None)
#  |      Serialize the pipeline to a Protobuf string.
#  |
#  |      Additionally, you can pass file name, so that serialized pipeline will be written there.
#  |      The file contents will be overwritten
#  |
#  |      Parameters
#  |      ----------
#  |      define_graph : allable
#  |              If specified, this function will be used instead of member :meth:`define_graph`.
#  |              This parameter must not be set, if the pipeline outputs are specified with
#  |              :meth:`set_outputs`.
#  |      filename : str
#  |              File, from where serialized pipeline will be writeen.
#  |      kwargs : dict
#  |              Refer to Pipeline constructor for full list of arguments.
#  |
#  |  set_outputs(self, *output_data_nodes)
#  |      Set the outputs of the pipeline.
#  |
#  |      Use of this function is an alternative to overriding `define_graph` in a derived class.
#  |
#  |      Args
#  |      ----
#  |      `*output_data_nodes` : unpacked list of :class:`DataNode` objects
#  |          The outputs of the pipeline
#  |
#  |  share_outputs(self)
#  |      Returns the outputs of the pipeline.
#  |
#  |      Main difference to :meth:`outputs`
#  |      is that share_outputs doesn't release returned buffers, release_outputs
#  |      need to be called for that. If the pipeline is executed asynchronously,
#  |      this function blocks until the results become available. It provides
#  |      the user with better control about when he wants to run the pipeline, when he wants
#  |      to obtain the resulting buffers and when they can be returned to DALI pool when the
#  |      results have been consumed.
#  |      Needs to be used together with :meth:`release_outputs`
#  |      and :meth:`schedule_run`
#  |      Should not be mixed with :meth:`run` in the same pipeline.
#  |
#  |      :return:
#  |          A list of `TensorList` objects for respective pipeline outputs
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  deserialize(serialized_pipeline=None, filename=None, **kwargs) from builtins.type
#  |      Deserialize and build pipeline.
#  |
#  |      Deserialize pipeline, previously serialized with ``serialize()`` method.
#  |
#  |      Returned pipeline is already built.
#  |
#  |      Alternatively, additional arguments can be passed, which will be used when instantiating
#  |      the pipeline. Refer to Pipeline constructor for full list of arguments. By default,
#  |      the pipeline will be instantiated with the arguments from serialized pipeline.
#  |
#  |      Note, that ``serialized_pipeline`` and ``filename`` parameters are mutually exclusive
#  |
#  |      Parameters
#  |      ----------
#  |      serialized_pipeline : str
#  |                 Pipeline, serialized using ``serialize()`` method.
#  |      filename : str
#  |                 File, from which serialized pipeline will be read.
#  |      kwargs : dict
#  |                 Refer to Pipeline constructor for full list of arguments.
#  |
#  |      Returns
#  |      ----------
#  |      Deserialized and built pipeline.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  current()
#  |
#  |  pop_current()
#  |      Restores previous pipeline as current. Complementary to :meth:`push_current`.
#  |
#  |  push_current(pipeline)
#  |      Sets the pipeline as current and stores the previous current pipeline
#  |      on stack. To restore previous pipeline as current, use :meth:`pop_current`.
#  |
#  |      To make sure that the pipeline is properly restored in case of exception, use context
#  |      manager (`with my_pipeline:`).
#  |
#  |      Current pipeline is required to call operators with side effects or without outputs.
#  |      Examples of such operators are `PythonFunction` (potential side effects) or `DumpImage`
#  |      (no output).
#  |
#  |      Any dangling operator can be marked as having side effects if it's marked
#  |      with `preserve=True`, which can be useful for debugging - otherwise operator which
#  |      does not contribute to the pipeline output is removed from the graph.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  batch_size
#  |      Batch size.
#  |
#  |  device_id
#  |      Id of the GPU used by the pipeline.
#  |
#  |  exec_async
#  |
#  |  exec_pipelined
#  |
#  |  num_threads
#  |      Number of CPU threads used by the pipeline.

# %%
import os.path
import fnmatch

for root, dir, files in os.walk("../cornell/"):
        depth = root.count('/')
        ret = ""
        if depth > 0:
            ret += "  " * (depth - 1) + "|-"
        print (ret + root)
        for items in fnmatch.filter(files, "*"):
                print (" " * len(ret) + "|-" + items)
# Out:
#   |-../cornell/
#   |-../cornell/01
#     |-pcd0199r.png
#     |-pcd0175r.png
#     |-pcd0190d.tiff
#     |-pcd0191cpos.txt
#     |-pcd0183.txt
#     |-pcd0104.txt
#     |-pcd0122.txt
#     |-pcd0110d.tiff
#     |-pcd0173d.tiff
#     |-pcd0111.txt
#     |-pcd0175.txt
#     |-pcd0143d.tiff
#     |-pcd0118r.png
#     |-pcd0140r.png
#     |-pcd0119.txt
#     |-pcd0132.txt
#     |-pcd0171r.png
#     |-pcd0124cneg.txt
#     |-pcd0105cpos.txt
#     |-pcd0181cpos.txt
#     |-pcd0131cneg.txt
#     |-pcd0157.txt
#     |-pcd0141cpos.txt
#     |-pcd0115cneg.txt
#     |-pcd0158.txt
#     |-pcd0133.txt
#     |-pcd0149cneg.txt
#     |-pcd0139.txt
#     |-pcd0145cpos.txt
#     |-pcd0150cpos.txt
#     |-pcd0151cneg.txt
#     |-pcd0144d.tiff
#     |-pcd0185cpos.txt
#     |-pcd0136.txt
#     |-pcd0127cpos.txt
#     |-pcd0110r.png
#     |-pcd0140d.tiff
#     |-pcd0119cpos.txt
#     |-pcd0119r.png
#     |-pcd0197r.png
#     |-pcd0102cneg.txt
#     |-pcd0144cpos.txt
#     |-pcd0191r.png
#     |-pcd0110cneg.txt
#     |-pcd0182.txt
#     |-pcd0161cneg.txt
#     |-pcd0130.txt
#     |-pcd0195cneg.txt
#     |-pcd0134cpos.txt
#     |-pcd0162cneg.txt
#     |-pcd0138d.tiff
#     |-pcd0179cpos.txt
#     |-pcd0138.txt
#     |-pcd0159cneg.txt
#     |-pcd0174r.png
#     |-pcd0174d.tiff
#     |-pcd0176cneg.txt
#     |-pcd0192d.tiff
#     |-pcd0133cneg.txt
#     |-pcd0121.txt
#     |-pcd0119d.tiff
#     |-pcd0134r.png
#     |-pcd0183cpos.txt
#     |-pcd0161d.tiff
#     |-pcd0107.txt
#     |-pcd0114cpos.txt
#     |-pcd0126cneg.txt
#     |-pcd0191d.tiff
#     |-pcd0126r.png
#     |-pcd0109cpos.txt
#     |-pcd0170r.png
#     |-pcd0153cneg.txt
#     |-pcd0162cpos.txt
#     |-pcd0169cpos.txt
#     |-pcd0150d.tiff
#     |-pcd0114r.png
#     |-pcd0163d.tiff
#     |-pcd0122cneg.txt
#     |-pcd0171cneg.txt
#     |-pcd0196d.tiff
#     |-pcd0134cneg.txt
#     |-pcd0111cneg.txt
#     |-pcd0128cneg.txt
#     |-pcd0123r.png
#     |-pcd0142cneg.txt
#     |-pcd0118cpos.txt
#     |-pcd0111r.png
#     |-pcd0170cpos.txt
#     |-pcd0161cpos.txt
#     |-pcd0144r.png
#     |-pcd0186r.png
#     |-pcd0165cpos.txt
#     |-pcd0142d.tiff
#     |-pcd0167.txt
#     |-pcd0148cpos.txt
#     |-pcd0130cpos.txt
#     |-pcd0150cneg.txt
#     |-pcd0118cneg.txt
#     |-pcd0135d.tiff
#     |-pcd0124r.png
#     |-pcd0132r.png
#     |-pcd0125.txt
#     |-pcd0180r.png
#     |-pcd0172d.tiff
#     |-pcd0147d.tiff
#     |-pcd0149d.tiff
#     |-pcd0129d.tiff
#     |-pcd0113r.png
#     |-pcd0125cpos.txt
#     |-pcd0189cneg.txt
#     |-pcd0198d.tiff
#     |-pcd0181d.tiff
#     |-pcd0116.txt
#     |-pcd0112cpos.txt
#     |-pcd0163cneg.txt
#     |-pcd0156cpos.txt
#     |-pcd0153cpos.txt
#     |-pcd0152cneg.txt
#     |-pcd0157d.tiff
#     |-pcd0160.txt
#     |-pcd0101cpos.txt
#     |-pcd0196cneg.txt
#     |-pcd0188.txt
#     |-pcd0179r.png
#     |-pcd0170.txt
#     |-pcd0138r.png
#     |-pcd0184cneg.txt
#     |-pcd0160d.tiff
#     |-pcd0157cneg.txt
#     |-pcd0154r.png
#     |-pcd0189.txt
#     |-pcd0140cneg.txt
#     |-pcd0103.txt
#     |-pcd0101d.tiff
#     |-pcd0176cpos.txt
#     |-pcd0199.txt
#     |-pcd0170cneg.txt
#     |-pcd0156r.png
#     |-pcd0144cneg.txt
#     |-pcd0131d.tiff
#     |-pcd0189cpos.txt
#     |-pcd0173cneg.txt
#     |-pcd0173.txt
#     |-pcd0138cneg.txt
#     |-pcd0193.txt
#     |-pcd0145r.png
#     |-pcd0105r.png
#     |-pcd0123d.tiff
#     |-pcd0150.txt
#     |-pcd0133d.tiff
#     |-pcd0103cpos.txt
#     |-pcd0155cneg.txt
#     |-pcd0178cpos.txt
#     |-pcd0178cneg.txt
#     |-pcd0181.txt
#     |-pcd0136r.png
#     |-pcd0176r.png
#     |-pcd0167cpos.txt
#     |-pcd0113.txt
#     |-pcd0159d.tiff
#     |-pcd0124.txt
#     |-pcd0190cneg.txt
#     |-pcd0118d.tiff
#     |-pcd0113cneg.txt
#     |-pcd0194.txt
#     |-pcd0185r.png
#     |-pcd0194cneg.txt
#     |-pcd0108cpos.txt
#     |-pcd0131r.png
#     |-pcd0121cpos.txt
#     |-pcd0160r.png
#     |-pcd0193d.tiff
#     |-pcd0186.txt
#     |-pcd0187r.png
#     |-pcd0115r.png
#     |-pcd0120r.png
#     |-pcd0163.txt
#     |-pcd0156.txt
#     |-pcd0106cneg.txt
#     |-pcd0179.txt
#     |-pcd0136cneg.txt
#     |-pcd0182r.png
#     |-pcd0198.txt
#     |-pcd0138cpos.txt
#   |-../cornell/08
#     |-pcd0848cpos.txt
#     |-pcd0848r.png
#     |-pcd0897r.png
#     |-pcd0899cneg.txt
#     |-pcd0838.txt
#     |-pcd0867.txt
#     |-pcd0895cneg.txt
#     |-pcd0860d.tiff
#     |-pcd0817cpos.txt
#     |-pcd0801cneg.txt
#     |-pcd0879r.png
#     |-pcd0876d.tiff
#     |-pcd0859.txt
#     |-pcd0880.txt
#     |-pcd0868cpos.txt
#     |-pcd0836cpos.txt
#     |-pcd0835r.png
#     |-pcd0895.txt
#     |-pcd0861cpos.txt
#     |-pcd0845d.tiff
#     |-pcd0867r.png
#     |-pcd0858cneg.txt
#     |-pcd0813r.png
#     |-pcd0802.txt
#     |-pcd0848.txt
#     |-pcd0884cneg.txt
#     |-pcd0860cpos.txt
#     |-pcd0853cpos.txt
#     |-pcd0864d.tiff
#     |-pcd0815r.png
#     |-pcd0898cpos.txt
#     |-pcd0821cpos.txt
#     |-pcd0803cneg.txt
#     |-pcd0830cpos.txt
#     |-pcd0891r.png
#     |-pcd0810cneg.txt
#     |-pcd0893d.tiff
#     |-pcd0844.txt
#     |-pcd0885cpos.txt
#     |-pcd0882cpos.txt
#     |-pcd0889r.png
#     |-pcd0845cneg.txt
#     |-pcd0850cneg.txt
#     |-pcd0834cneg.txt
#     |-pcd0868d.tiff
#     |-pcd0877cpos.txt
#     |-pcd0838r.png
#     |-pcd0818cpos.txt
#     |-pcd0871cpos.txt
#     |-pcd0822d.tiff
#     |-pcd0860cneg.txt
#     |-pcd0877d.tiff
#     |-pcd0852d.tiff
#     |-pcd0801d.tiff
#     |-pcd0843cpos.txt
#     |-pcd0834r.png
#     |-pcd0808.txt
#     |-pcd0839cneg.txt
#     |-pcd0875.txt
#     |-pcd0884.txt
#     |-pcd0870.txt
#     |-pcd0854.txt
#     |-pcd0825r.png
#     |-pcd0873cpos.txt
#     |-pcd0881d.tiff
#     |-pcd0832.txt
#     |-pcd0865cpos.txt
#     |-pcd0845cpos.txt
#     |-pcd0893cneg.txt
#     |-pcd0844r.png
#     |-pcd0857.txt
#     |-pcd0861d.tiff
#     |-pcd0898cneg.txt
#     |-pcd0820cpos.txt
#     |-pcd0811d.tiff
#     |-pcd0841r.png
#     |-pcd0893cpos.txt
#     |-pcd0862.txt
#     |-pcd0818d.tiff
#     |-pcd0862r.png
#     |-pcd0835cneg.txt
#     |-pcd0867cneg.txt
#     |-pcd0808cneg.txt
#     |-pcd0812d.tiff
#     |-pcd0846cneg.txt
#     |-pcd0869r.png
#     |-pcd0837.txt
#     |-pcd0857cpos.txt
#     |-pcd0876r.png
#     |-pcd0822cneg.txt
#     |-pcd0851r.png
#     |-pcd0871cneg.txt
#     |-pcd0888d.tiff
#     |-pcd0800cpos.txt
#     |-pcd0849r.png
#     |-pcd0806d.tiff
#     |-pcd0801cpos.txt
#     |-pcd0875cneg.txt
#     |-pcd0881.txt
#     |-pcd0842cpos.txt
#     |-pcd0850cpos.txt
#     |-pcd0858r.png
#     |-pcd0815d.tiff
#     |-pcd0872r.png
#     |-pcd0854cpos.txt
#     |-pcd0863r.png
#     |-pcd0813cneg.txt
#     |-pcd0899cpos.txt
#     |-pcd0841cpos.txt
#     |-pcd0884d.tiff
#     |-pcd0897cneg.txt
#     |-pcd0832r.png
#     |-pcd0809cneg.txt
#     |-pcd0822cpos.txt
#     |-pcd0885cneg.txt
#     |-pcd0870cpos.txt
#     |-pcd0849.txt
#     |-pcd0811.txt
#     |-pcd0825cpos.txt
#     |-pcd0858d.tiff
#     |-pcd0863d.tiff
#     |-pcd0830d.tiff
#     |-pcd0803d.tiff
#     |-pcd0881r.png
#     |-pcd0817d.tiff
#     |-pcd0819cneg.txt
#     |-pcd0890d.tiff
#     |-pcd0873cneg.txt
#     |-pcd0880d.tiff
#     |-pcd0832cpos.txt
#     |-pcd0839d.tiff
#     |-pcd0889d.tiff
#     |-pcd0899.txt
#     |-pcd0855cneg.txt
#     |-pcd0860r.png
#     |-pcd0811cneg.txt
#     |-pcd0882r.png
#     |-pcd0836r.png
#     |-pcd0821d.tiff
#     |-pcd0865cneg.txt
#     |-pcd0819r.png
#     |-pcd0830r.png
#     |-pcd0828cpos.txt
#     |-pcd0815cneg.txt
#     |-pcd0849cpos.txt
#     |-pcd0803cpos.txt
#     |-pcd0856r.png
#     |-pcd0807r.png
#     |-pcd0898d.tiff
#     |-pcd0814.txt
#     |-pcd0816d.tiff
#     |-pcd0805cpos.txt
#     |-pcd0857d.tiff
#     |-pcd0885d.tiff
#     |-pcd0866cpos.txt
#     |-pcd0844d.tiff
#     |-pcd0812cpos.txt
#     |-pcd0894.txt
#     |-pcd0828r.png
#     |-pcd0866cneg.txt
#     |-pcd0806.txt
#     |-pcd0845.txt
#     |-pcd0810r.png
#     |-pcd0803r.png
#     |-pcd0896d.tiff
#     |-pcd0843d.tiff
#     |-pcd0856d.tiff
#     |-pcd0827cneg.txt
#     |-pcd0851d.tiff
#     |-pcd0873.txt
#     |-pcd0823d.tiff
#     |-pcd0888.txt
#     |-pcd0895d.tiff
#     |-pcd0859r.png
#     |-pcd0833cpos.txt
#     |-pcd0809.txt
#     |-pcd0866d.tiff
#     |-pcd0882d.tiff
#     |-pcd0861cneg.txt
#     |-pcd0886cneg.txt
#     |-pcd0876cneg.txt
#     |-pcd0854r.png
#     |-pcd0859cneg.txt
#     |-pcd0871.txt
#     |-pcd0890cneg.txt
#     |-pcd0822.txt
#     |-pcd0810d.tiff
#     |-pcd0874d.tiff
#     |-pcd0822r.png
#     |-pcd0841cneg.txt
#     |-pcd0898.txt
#     |-pcd0833.txt
#     |-pcd0883.txt
#     |-pcd0840.txt
#     |-pcd0879cpos.txt
#     |-pcd0838cneg.txt
#     |-pcd0880cpos.txt
#     |-pcd0863.txt
#     |-pcd0847cpos.txt
#     |-pcd0875cpos.txt
#     |-pcd0874cneg.txt
#     |-pcd0885r.png
#     |-pcd0835.txt
#     |-pcd0835cpos.txt
#     |-pcd0837d.tiff
#     |-pcd0852cneg.txt
#     |-pcd0862d.tiff
#     |-pcd0878r.png
#     |-pcd0848d.tiff
#     |-pcd0867cpos.txt
#     |-pcd0847d.tiff
#     |-pcd0853r.png
#     |-pcd0870d.tiff
#     |-pcd0855.txt
#     |-pcd0894d.tiff
#     |-pcd0892d.tiff
#     |-pcd0818r.png
#     |-pcd0863cneg.txt
#     |-pcd0819.txt
#     |-pcd0865r.png
#     |-pcd0846.txt
#     |-pcd0889cneg.txt
#     |-pcd0841d.tiff
#     |-pcd0831.txt
#     |-pcd0809cpos.txt
#     |-pcd0829r.png
#     |-pcd0896r.png
#     |-pcd0873d.tiff
#     |-pcd0826cpos.txt
#     |-pcd0847cneg.txt
#     |-pcd0894cpos.txt
#     |-pcd0817r.png
#     |-pcd0832cneg.txt
#     |-pcd0824r.png
#     |-pcd0886d.tiff
#     |-pcd0816r.png
#     |-pcd0862cpos.txt
#     |-pcd0878cpos.txt
#     |-pcd0853d.tiff
#     |-pcd0851.txt
#     |-pcd0898r.png
#     |-pcd0817cneg.txt
#     |-pcd0842r.png
#     |-pcd0887.txt
#     |-pcd0887r.png
#     |-pcd0839r.png
#     |-pcd0808cpos.txt
#     |-pcd0833r.png
#     |-pcd0831d.tiff
#     |-pcd0837cpos.txt
#     |-pcd0877r.png
#     |-pcd0854cneg.txt
#     |-pcd0879d.tiff
#     |-pcd0820.txt
#     |-pcd0827r.png
#     |-pcd0888cneg.txt
#     |-pcd0800cneg.txt
#     |-pcd0879cneg.txt
#     |-pcd0836.txt
#     |-pcd0887d.tiff
#     |-pcd0805r.png
#     |-pcd0886cpos.txt
#     |-pcd0829.txt
#     |-pcd0850d.tiff
#     |-pcd0816.txt
#     |-pcd0828.txt
#     |-pcd0826r.png
#     |-pcd0855r.png
#     |-pcd0829d.tiff
#     |-pcd0899d.tiff
#     |-pcd0893.txt
#     |-pcd0864cneg.txt
#     |-pcd0887cpos.txt
#     |-pcd0825cneg.txt
#     |-pcd0895r.png
#     |-pcd0819cpos.txt
#     |-pcd0863cpos.txt
#     |-pcd0814d.tiff
#     |-pcd0814cneg.txt
#     |-pcd0827d.tiff
#     |-pcd0868r.png
#     |-pcd0882.txt
#     |-pcd0869d.tiff
#     |-pcd0894cneg.txt
#     |-pcd0816cneg.txt
#     |-pcd0892cpos.txt
#     |-pcd0817.txt
#     |-pcd0883cneg.txt
#     |-pcd0834cpos.txt
#     |-pcd0825d.tiff
#     |-pcd0814r.png
#     |-pcd0869cpos.txt
#     |-pcd0883d.tiff
#     |-pcd0865d.tiff
#     |-pcd0828d.tiff
#     |-pcd0830cneg.txt
#     |-pcd0843cneg.txt
#     |-pcd0864cpos.txt
#     |-pcd0836d.tiff
#     |-pcd0806cneg.txt
#     |-pcd0880cneg.txt
#     |-pcd0858cpos.txt
#     |-pcd0892cneg.txt
#     |-pcd0840r.png
#     |-pcd0890r.png
#     |-pcd0839cpos.txt
#     |-pcd0871d.tiff
#     |-pcd0852r.png
#     |-pcd0804d.tiff
#     |-pcd0856cneg.txt
#     |-pcd0809r.png
#     |-pcd0831r.png
#     |-pcd0836cneg.txt
#     |-pcd0842d.tiff
#     |-pcd0837r.png
#     |-pcd0865.txt
#     |-pcd0894r.png
#     |-pcd0801r.png
#     |-pcd0891.txt
#     |-pcd0846r.png
#     |-pcd0893r.png
#     |-pcd0853.txt
#     |-pcd0891cpos.txt
#     |-pcd0874cpos.txt
#     |-pcd0899r.png
#     |-pcd0849cneg.txt
#     |-pcd0853cneg.txt
#     |-pcd0896.txt
#     |-pcd0839.txt
#     |-pcd0859d.tiff
#     |-pcd0838cpos.txt
#     |-pcd0821r.png
#     |-pcd0875r.png
#     |-pcd0855d.tiff
#     |-pcd0896cpos.txt
#     |-pcd0829cneg.txt
#     |-pcd0889cpos.txt
#     |-pcd0816cpos.txt
#     |-pcd0837cneg.txt
#     |-pcd0851cpos.txt
#     |-pcd0802r.png
#     |-pcd0857r.png
#     |-pcd0878d.tiff
#     |-pcd0862cneg.txt
#     |-pcd0895cpos.txt
#     |-pcd0852cpos.txt
#     |-pcd0861r.png
#     |-pcd0809d.tiff
#     |-pcd0838d.tiff
#     |-pcd0845r.png
#     |-pcd0842.txt
#     |-pcd0851cneg.txt
#     |-pcd0804r.png
#     |-pcd0891cneg.txt
#     |-pcd0869cneg.txt
#     |-pcd0860.txt
#     |-pcd0827.txt
#     |-pcd0876.txt
#     |-pcd0812cneg.txt
#     |-pcd0810.txt
#     |-pcd0828cneg.txt
#     |-pcd0868cneg.txt
#     |-pcd0841.txt
#     |-pcd0864.txt
#     |-pcd0811r.png
#     |-pcd0888cpos.txt
#     |-pcd0890.txt
#     |-pcd0840cneg.txt
#     |-pcd0833cneg.txt
#     |-pcd0820cneg.txt
#     |-pcd0807.txt
#     |-pcd0802cpos.txt
#     |-pcd0877.txt
#     |-pcd0867d.tiff
#     |-pcd0854d.tiff
#     |-pcd0884cpos.txt
#     |-pcd0803.txt
#     |-pcd0823.txt
#     |-pcd0800r.png
#     |-pcd0874r.png
#     |-pcd0885.txt
#     |-pcd0878.txt
#     |-pcd0833d.tiff
#     |-pcd0821cneg.txt
#     |-pcd0866.txt
#     |-pcd0879.txt
#     |-pcd0824cpos.txt
#     |-pcd0813d.tiff
#     |-pcd0821.txt
#     |-pcd0825.txt
#     |-pcd0892.txt
#     |-pcd0872d.tiff
#     |-pcd0831cpos.txt
#     |-pcd0859cpos.txt
#     |-pcd0832d.tiff
#     |-pcd0824cneg.txt
#     |-pcd0824.txt
#     |-pcd0842cneg.txt
#     |-pcd0883r.png
#     |-pcd0805cneg.txt
#     |-pcd0844cpos.txt
#     |-pcd0848cneg.txt
#     |-pcd0881cpos.txt
#     |-pcd0856.txt
#     |-pcd0808r.png
#     |-pcd0823cneg.txt
#     |-pcd0804.txt
#     |-pcd0855cpos.txt
#     |-pcd0870cneg.txt
#     |-pcd0806r.png
#     |-pcd0844cneg.txt
#     |-pcd0802cneg.txt
#     |-pcd0840cpos.txt
#     |-pcd0872cneg.txt
#     |-pcd0820d.tiff
#     |-pcd0823cpos.txt
#     |-pcd0807cneg.txt
#     |-pcd0807cpos.txt
#     |-pcd0871r.png
#     |-pcd0852.txt
#     |-pcd0876cpos.txt
#     |-pcd0878cneg.txt
#     |-pcd0857cneg.txt
#     |-pcd0866r.png
#     |-pcd0890cpos.txt
#     |-pcd0887cneg.txt
#     |-pcd0875d.tiff
#     |-pcd0818cneg.txt
#     |-pcd0810cpos.txt
#     |-pcd0819d.tiff
#     |-pcd0850r.png
#     |-pcd0849d.tiff
#     |-pcd0858.txt
#     |-pcd0826.txt
#     |-pcd0807d.tiff
#     |-pcd0811cpos.txt
#     |-pcd0856cpos.txt
#     |-pcd0827cpos.txt
#     |-pcd0813.txt
#     |-pcd0850.txt
#     |-pcd0896cneg.txt
#     |-pcd0804cpos.txt
#     |-pcd0818.txt
#     |-pcd0870r.png
#     |-pcd0882cneg.txt
#     |-pcd0897cpos.txt
#     |-pcd0846d.tiff
#     |-pcd0804cneg.txt
#     |-pcd0888r.png
#     |-pcd0834.txt
#     |-pcd0861.txt
#     |-pcd0873r.png
#     |-pcd0824d.tiff
#     |-pcd0872.txt
#     |-pcd0826cneg.txt
#     |-pcd0830.txt
#     |-pcd0869.txt
#     |-pcd0814cpos.txt
#     |-pcd0835d.tiff
#     |-pcd0806cpos.txt
#     |-pcd0884r.png
#     |-pcd0805d.tiff
#     |-pcd0834d.tiff
#     |-pcd0843.txt
#     |-pcd0840d.tiff
#     |-pcd0874.txt
#     |-pcd0831cneg.txt
#     |-pcd0823r.png
#     |-pcd0881cneg.txt
#     |-pcd0805.txt
#     |-pcd0872cpos.txt
#     |-pcd0815cpos.txt
#     |-pcd0801.txt
#     |-pcd0846cpos.txt
#     |-pcd0808d.tiff
#     |-pcd0847.txt
#     |-pcd0864r.png
#     |-pcd0868.txt
#     |-pcd0889.txt
#     |-pcd0800d.tiff
#     |-pcd0883cpos.txt
#     |-pcd0892r.png
#     |-pcd0847r.png
#     |-pcd0843r.png
#     |-pcd0880r.png
#     |-pcd0826d.tiff
#     |-pcd0820r.png
#     |-pcd0877cneg.txt
#     |-pcd0815.txt
#     |-pcd0812.txt
#     |-pcd0886.txt
#     |-pcd0802d.tiff
#     |-pcd0829cpos.txt
#     |-pcd0897d.tiff
#     |-pcd0886r.png
#     |-pcd0891d.tiff
#     |-pcd0897.txt
#     |-pcd0813cpos.txt
#     |-pcd0800.txt
#     |-pcd0812r.png
#   |-../cornell/09
#     |-pcd0924d.tiff
#     |-pcd0934.txt
#     |-pcd0943cneg.txt
#     |-pcd0916cneg.txt
#     |-pcd0927cpos.txt
#     |-pcd0929cneg.txt
#     |-pcd0912cpos.txt
#     |-pcd0948d.tiff
#     |-pcd0931d.tiff
#     |-pcd0941d.tiff
#     |-pcd0921cneg.txt
#     |-pcd0921d.tiff
#     |-pcd0906d.tiff
#     |-pcd0903r.png
#     |-pcd0912.txt
#     |-pcd0925.txt
#     |-pcd0909cpos.txt
#     |-pcd0942.txt
#     |-pcd0905cneg.txt
#     |-pcd0942cneg.txt
#     |-pcd0917r.png
#     |-pcd0918cpos.txt
#     |-pcd0943r.png
#     |-pcd0906cneg.txt
#     |-pcd0936.txt
#     |-pcd0907d.tiff
#     |-pcd0932d.tiff
#     |-pcd0900cpos.txt
#     |-pcd0906cpos.txt
#     |-pcd0907cneg.txt
#     |-pcd0939cneg.txt
#     |-pcd0948cpos.txt
#     |-pcd0948r.png
#     |-pcd0913d.tiff
#     |-pcd0946.txt
#     |-pcd0934r.png
#     |-pcd0902r.png
#     |-pcd0935.txt
#     |-pcd0920d.tiff
#     |-pcd0930cneg.txt
#     |-pcd0907cpos.txt
#     |-pcd0946r.png
#     |-pcd0912r.png
#     |-pcd0904.txt
#     |-pcd0911r.png
#     |-pcd0931cneg.txt
#     |-pcd0928.txt
#     |-pcd0946cpos.txt
#     |-pcd0936r.png
#     |-pcd0913r.png
#     |-pcd0943.txt
#     |-pcd0922d.tiff
#     |-pcd0907r.png
#     |-pcd0908r.png
#     |-pcd0940d.tiff
#     |-pcd0927cneg.txt
#     |-pcd0914cpos.txt
#     |-pcd0945r.png
#     |-pcd0910cpos.txt
#     |-pcd0909cneg.txt
#     |-pcd0925cneg.txt
#     |-pcd0937d.tiff
#     |-pcd0939d.tiff
#     |-pcd0949.txt
#     |-pcd0939r.png
#     |-pcd0924cpos.txt
#     |-pcd0932.txt
#     |-pcd0917d.tiff
#     |-pcd0931cpos.txt
#     |-pcd0915cneg.txt
#     |-pcd0908cneg.txt
#     |-pcd0927.txt
#     |-pcd0903.txt
#     |-pcd0915r.png
#     |-pcd0935r.png
#     |-pcd0900d.tiff
#     |-pcd0907.txt
#     |-pcd0938cpos.txt
#     |-pcd0928d.tiff
#     |-pcd0902cpos.txt
#     |-pcd0947d.tiff
#     |-pcd0915d.tiff
#     |-pcd0913cneg.txt
#     |-pcd0921r.png
#     |-pcd0945.txt
#     |-pcd0949d.tiff
#     |-pcd0905.txt
#     |-pcd0946cneg.txt
#     |-pcd0918r.png
#     |-pcd0901cneg.txt
#     |-pcd0940r.png
#     |-pcd0914r.png
#     |-pcd0917cneg.txt
#     |-pcd0943cpos.txt
#     |-pcd0943d.tiff
#     |-pcd0901cpos.txt
#     |-pcd0922cneg.txt
#     |-pcd0937cpos.txt
#     |-pcd0914cneg.txt
#     |-pcd0926d.tiff
#     |-pcd0933cneg.txt
#     |-pcd0902d.tiff
#     |-pcd0902cneg.txt
#     |-pcd0946d.tiff
#     |-pcd0934cpos.txt
#     |-pcd0924r.png
#     |-pcd0920.txt
#     |-pcd0905r.png
#     |-pcd0901.txt
#     |-pcd0916r.png
#     |-pcd0940.txt
#     |-pcd0923cpos.txt
#     |-pcd0901r.png
#     |-pcd0926r.png
#     |-pcd0905d.tiff
#     |-pcd0928cneg.txt
#     |-pcd0945cpos.txt
#     |-pcd0910d.tiff
#     |-pcd0904cpos.txt
#     |-pcd0918.txt
#     |-pcd0944cneg.txt
#     |-pcd0920cpos.txt
#     |-pcd0928r.png
#     |-pcd0942cpos.txt
#     |-pcd0920cneg.txt
#     |-pcd0908d.tiff
#     |-pcd0914d.tiff
#     |-pcd0941cpos.txt
#     |-pcd0906.txt
#     |-pcd0918d.tiff
#     |-pcd0944.txt
#     |-pcd0931.txt
#     |-pcd0942d.tiff
#     |-pcd0949cpos.txt
#     |-pcd0938cneg.txt
#     |-pcd0932r.png
#     |-pcd0930cpos.txt
#     |-pcd0909d.tiff
#     |-pcd0935d.tiff
#     |-pcd0934cneg.txt
#     |-pcd0945d.tiff
#     |-pcd0901d.tiff
#     |-pcd0941r.png
#     |-pcd0925d.tiff
#     |-pcd0944cpos.txt
#     |-pcd0936d.tiff
#     |-pcd0933d.tiff
#     |-pcd0937.txt
#     |-pcd0936cneg.txt
#     |-pcd0915cpos.txt
#     |-pcd0916d.tiff
#     |-pcd0905cpos.txt
#     |-pcd0948.txt
#     |-pcd0911.txt
#     |-pcd0915.txt
#     |-pcd0939.txt
#     |-pcd0945cneg.txt
#     |-pcd0903cpos.txt
#     |-pcd0900cneg.txt
#     |-pcd0938r.png
#     |-pcd0923d.tiff
#     |-pcd0930d.tiff
#     |-pcd0904r.png
#     |-pcd0906r.png
#     |-pcd0908cpos.txt
#     |-pcd0947cneg.txt
#     |-pcd0919cneg.txt
#     |-pcd0910.txt
#     |-pcd0923r.png
#     |-pcd0923.txt
#     |-pcd0903cneg.txt
#     |-pcd0947cpos.txt
#     |-pcd0938d.tiff
#     |-pcd0909.txt
#     |-pcd0919r.png
#     |-pcd0919cpos.txt
#     |-pcd0923cneg.txt
#     |-pcd0914.txt
#     |-pcd0922.txt
#     |-pcd0929.txt
#     |-pcd0924cneg.txt
#     |-pcd0931r.png
#     |-pcd0937r.png
#     |-pcd0912d.tiff
#     |-pcd0940cneg.txt
#     |-pcd0900.txt
#     |-pcd0935cneg.txt
#     |-pcd0910cneg.txt
#     |-pcd0913cpos.txt
#     |-pcd0935cpos.txt
#     |-pcd0932cneg.txt
#     |-pcd0926.txt
#     |-pcd0939cpos.txt
#     |-pcd0900r.png
#     |-pcd0941.txt
#     |-pcd0917cpos.txt
#     |-pcd0929r.png
#     |-pcd0928cpos.txt
#     |-pcd0908.txt
#     |-pcd0913.txt
#     |-pcd0910r.png
#     |-pcd0916cpos.txt
#     |-pcd0902.txt
#     |-pcd0933.txt
#     |-pcd0947r.png
#     |-pcd0933cpos.txt
#     |-pcd0936cpos.txt
#     |-pcd0911d.tiff
#     |-pcd0926cneg.txt
#     |-pcd0922cpos.txt
#     |-pcd0921cpos.txt
#     |-pcd0930.txt
#     |-pcd0924.txt
#     |-pcd0940cpos.txt
#     |-pcd0932cpos.txt
#     |-pcd0938.txt
#     |-pcd0925cpos.txt
#     |-pcd0909r.png
#     |-pcd0919d.tiff
#     |-pcd0944r.png
#     |-pcd0921.txt
#     |-pcd0944d.tiff
#     |-pcd0927d.tiff
#     |-pcd0920r.png
#     |-pcd0929d.tiff
#     |-pcd0917.txt
#     |-pcd0942r.png
#     |-pcd0941cneg.txt
#     |-pcd0922r.png
#     |-pcd0904d.tiff
#     |-pcd0903d.tiff
#     |-pcd0918cneg.txt
#     |-pcd0948cneg.txt
#     |-pcd0949r.png
#     |-pcd0766.txt
#     |-pcd0764d.tiff
#     |-pcd0717d.tiff
#     |-pcd0711d.tiff
#     |-pcd0718r.png
#     |-pcd0722r.png
#     |-pcd0724cneg.txt
#     |-pcd0732.txt
#     |-pcd0799cpos.txt
#     |-pcd0761r.png
#     |-pcd0765cneg.txt
#     |-pcd0707cneg.txt
#     |-pcd0792d.tiff
#     |-pcd0723.txt
#     |-pcd0790cneg.txt
#     |-pcd0793cneg.txt
#     |-pcd0757d.tiff
#     |-pcd0744d.tiff
#     |-pcd0765cpos.txt
#     |-pcd0751d.tiff
#     |-pcd0716cneg.txt
#     |-pcd0795r.png
#     |-pcd0718cneg.txt
#     |-pcd0789cpos.txt
#     |-pcd0758cpos.txt
#     |-pcd0767d.tiff
#     |-pcd0709r.png
#     |-pcd0766cneg.txt
#     |-pcd0739r.png
#     |-pcd0779cneg.txt
#     |-pcd0777d.tiff
#     |-pcd0746r.png
#     |-pcd0710cneg.txt
#     |-pcd0763cneg.txt
#     |-pcd0708cneg.txt
#     |-pcd0752cpos.txt
#     |-pcd0763r.png
#     |-pcd0703d.tiff
#     |-pcd0781cneg.txt
#     |-pcd0719.txt
#     |-pcd0741.txt
#     |-pcd0757.txt
#     |-pcd0742r.png
#     |-pcd0787d.tiff
#     |-pcd0745d.tiff
#     |-pcd0700d.tiff
#     |-pcd0775.txt
#     |-pcd0748.txt
#     |-pcd0791.txt
#     |-pcd0730d.tiff
#     |-pcd0763cpos.txt
#     |-pcd0776d.tiff
#     |-pcd0798d.tiff
#     |-pcd0771d.tiff
#     |-pcd0771r.png
#     |-pcd0768cpos.txt
#     |-pcd0722d.tiff
#     |-pcd0740.txt
#     |-pcd0753cpos.txt
#     |-pcd0787r.png
#     |-pcd0776cneg.txt
#     |-pcd0747cneg.txt
#     |-pcd0726cpos.txt
#     |-pcd0753cneg.txt
#     |-pcd0754cpos.txt
#     |-pcd0720cpos.txt
#     |-pcd0780r.png
#     |-pcd0737.txt
#     |-pcd0709d.tiff
#     |-pcd0773cpos.txt
#     |-pcd0744.txt
#     |-pcd0749cpos.txt
#     |-pcd0777cpos.txt
#     |-pcd0780d.tiff
#     |-pcd0799r.png
#     |-pcd0715r.png
#     |-pcd0731r.png
#     |-pcd0780cneg.txt
#     |-pcd0784r.png
#     |-pcd0779r.png
#     |-pcd0729.txt
#     |-pcd0725cpos.txt
#     |-pcd0794cneg.txt
#     |-pcd0751.txt
#     |-pcd0797.txt
#     |-pcd0750r.png
#     |-pcd0777.txt
#     |-pcd0750d.tiff
#     |-pcd0712r.png
#     |-pcd0760d.tiff
#     |-pcd0702cneg.txt
#     |-pcd0792cneg.txt
#     |-pcd0774d.tiff
#     |-pcd0730cpos.txt
#     |-pcd0756cneg.txt
#   |-../cornell/06
#     |-pcd0677.txt
#     |-pcd0697cpos.txt
#     |-pcd0661cpos.txt
#     |-pcd0607r.png
#     |-pcd0668.txt
#     |-pcd0637.txt
#     |-pcd0664r.png
#     |-pcd0695.txt
#     |-pcd0690r.png
#     |-pcd0615d.tiff
#     |-pcd0698cpos.txt
#     |-pcd0654d.tiff
#     |-pcd0659.txt
#     |-pcd0650d.tiff
#     |-pcd0693r.png
#     |-pcd0649cpos.txt
#     |-pcd0649cneg.txt
#     |-pcd0695r.png
#     |-pcd0602cneg.txt
#     |-pcd0642d.tiff
#     |-pcd0620cneg.txt
#     |-pcd0618d.tiff
#     |-pcd0694.txt
#     |-pcd0674.txt
#     |-pcd0612d.tiff
#     |-pcd0657r.png
#     |-pcd0661.txt
#     |-pcd0697d.tiff
#     |-pcd0636cneg.txt
#     |-pcd0646d.tiff
#     |-pcd0622cpos.txt
#     |-pcd0663r.png
#     |-pcd0649d.tiff
#     |-pcd0630.txt
#     |-pcd0633cneg.txt
#     |-pcd0666d.tiff
#     |-pcd0638cneg.txt
#     |-pcd0638cpos.txt
#     |-pcd0683cneg.txt
#     |-pcd0675d.tiff
#     |-pcd0625cpos.txt
#     |-pcd0644cneg.txt
#     |-pcd0623d.tiff
#     |-pcd0669r.png
#     |-pcd0622r.png
#     |-pcd0689cpos.txt
#     |-pcd0620r.png
#     |-pcd0659cneg.txt
#     |-pcd0605.txt
#     |-pcd0694cpos.txt
#     |-pcd0655d.tiff
#     |-pcd0652cneg.txt
#     |-pcd0648cpos.txt
#     |-pcd0684d.tiff
#     |-pcd0647cpos.txt
#     |-pcd0603r.png
#     |-pcd0617r.png
#     |-pcd0656r.png
#     |-pcd0673cneg.txt
#     |-pcd0653r.png
#     |-pcd0654cpos.txt
#     |-pcd0635d.tiff
#     |-pcd0603cpos.txt
#     |-pcd0605cpos.txt
#     |-pcd0686cpos.txt
#     |-pcd0662.txt
#     |-pcd0613.txt
#     |-pcd0666.txt
#     |-pcd0657cpos.txt
#     |-pcd0658.txt
#     |-pcd0670r.png
#     |-pcd0633d.tiff
#     |-pcd0620.txt
#     |-pcd0692cneg.txt
#     |-pcd0659r.png
#     |-pcd0621r.png
#     |-pcd0694d.tiff
#     |-pcd0604.txt
#     |-pcd0642cpos.txt
#     |-pcd0688cneg.txt
#     |-pcd0600cneg.txt
#     |-pcd0690d.tiff
#     |-pcd0600.txt
#     |-pcd0652r.png
#     |-pcd0652.txt
#     |-pcd0633cpos.txt
#     |-pcd0605cneg.txt
#     |-pcd0629cpos.txt
#     |-pcd0609d.tiff
#     |-pcd0628cpos.txt
#     |-pcd0617cpos.txt
#     |-pcd0644d.tiff
#     |-pcd0673cpos.txt
#     |-pcd0699d.tiff
#     |-pcd0614cpos.txt
#     |-pcd0639.txt
#     |-pcd0660.txt
#     |-pcd0699cpos.txt
#     |-pcd0692cpos.txt
#     |-pcd0649.txt
#     |-pcd0629cneg.txt
#     |-pcd0687.txt
#     |-pcd0686cneg.txt
#     |-pcd0613r.png
#     |-pcd0653cneg.txt
#     |-pcd0677d.tiff
#     |-pcd0676r.png
#     |-pcd0606d.tiff
#     |-pcd0610d.tiff
#     |-pcd0633.txt
#     |-pcd0618cneg.txt
#     |-pcd0682cneg.txt
#     |-pcd0626r.png
#     |-pcd0612cpos.txt
#     |-pcd0600cpos.txt
#     |-pcd0680r.png
#     |-pcd0632r.png
#     |-pcd0612.txt
#     |-pcd0681cneg.txt
#     |-pcd0678r.png
#     |-pcd0678cneg.txt
#     |-pcd0610cneg.txt
#     |-pcd0676cneg.txt
#     |-pcd0618r.png
#     |-pcd0646r.png
#     |-pcd0686r.png
#     |-pcd0675cneg.txt
#     |-pcd0660cneg.txt
#     |-pcd0653d.tiff
#     |-pcd0615cneg.txt
#     |-pcd0659d.tiff
#     |-pcd0662d.tiff
#     |-pcd0617d.tiff
#     |-pcd0679r.png
#     |-pcd0644cpos.txt
#     |-pcd0641cpos.txt
#     |-pcd0614d.tiff
#     |-pcd0690.txt
#     |-pcd0608cpos.txt
#     |-pcd0691cpos.txt
#     |-pcd0646cpos.txt
#     |-pcd0634r.png
#     |-pcd0635cpos.txt
#     |-pcd0643cpos.txt
#     |-pcd0656cpos.txt
#     |-pcd0612r.png
#     |-pcd0653cpos.txt
#     |-pcd0667d.tiff
#     |-pcd0620cpos.txt
#     |-pcd0602cpos.txt
#     |-pcd0607d.tiff
#     |-pcd0625cneg.txt
#     |-pcd0624cpos.txt
#     |-pcd0687r.png
#     |-pcd0606cpos.txt
#     |-pcd0670d.tiff
#     |-pcd0699cneg.txt
#     |-pcd0611cneg.txt
#     |-pcd0625r.png
#     |-pcd0679.txt
#     |-pcd0683.txt
#     |-pcd0651d.tiff
#     |-pcd0698.txt
#     |-pcd0675r.png
#     |-pcd0674cpos.txt
#     |-pcd0631r.png
#     |-pcd0609cneg.txt
#     |-pcd0658cneg.txt
#     |-pcd0681.txt
#     |-pcd0628d.tiff
#     |-pcd0685cpos.txt
#     |-pcd0602.txt
#     |-pcd0666cpos.txt
#     |-pcd0635.txt
#     |-pcd0689r.png
#     |-pcd0635r.png
#     |-pcd0662cneg.txt
#     |-pcd0673r.png
#     |-pcd0655cneg.txt
#     |-pcd0617cneg.txt
#     |-pcd0680.txt
#     |-pcd0635cneg.txt
#     |-pcd0616cpos.txt
#     |-pcd0648.txt
#     |-pcd0611cpos.txt
#     |-pcd0603d.tiff
#     |-pcd0669d.tiff
#     |-pcd0663cneg.txt
#     |-pcd0681cpos.txt
#     |-pcd0684cpos.txt
#     |-pcd0623cpos.txt
#     |-pcd0673d.tiff
#     |-pcd0654r.png
#     |-pcd0699.txt
#     |-pcd0625d.tiff
#     |-pcd0665cneg.txt
#     |-pcd0606r.png
#     |-pcd0663d.tiff
#     |-pcd0687cneg.txt
#     |-pcd0643d.tiff
#     |-pcd0688r.png
#     |-pcd0607.txt
#     |-pcd0610r.png
#     |-pcd0680cneg.txt
#     |-pcd0639cneg.txt
#     |-pcd0615cpos.txt
#     |-pcd0629.txt
#     |-pcd0667.txt
#     |-pcd0656cneg.txt
#     |-pcd0698r.png
#     |-pcd0654cneg.txt
#     |-pcd0688cpos.txt
#     |-pcd0682r.png
#     |-pcd0697r.png
#     |-pcd0683r.png
#     |-pcd0619cpos.txt
#     |-pcd0629r.png
#     |-pcd0640cneg.txt
#     |-pcd0693d.tiff
#     |-pcd0650cneg.txt
#     |-pcd0643r.png
#     |-pcd0658r.png
#     |-pcd0631d.tiff
#     |-pcd0621cpos.txt
#     |-pcd0641r.png
#     |-pcd0638r.png
#     |-pcd0690cneg.txt
#     |-pcd0682.txt
#     |-pcd0683d.tiff
#     |-pcd0683cpos.txt
#     |-pcd0696cpos.txt
#     |-pcd0639d.tiff
#     |-pcd0615r.png
#     |-pcd0608d.tiff
#     |-pcd0693.txt
#     |-pcd0638.txt
#     |-pcd0692r.png
#     |-pcd0618cpos.txt
#     |-pcd0643cneg.txt
#     |-pcd0601cneg.txt
#     |-pcd0616d.tiff
#     |-pcd0644.txt
#     |-pcd0688.txt
#     |-pcd0631.txt
#     |-pcd0628.txt
#     |-pcd0653.txt
#     |-pcd0637r.png
#     |-pcd0624cneg.txt
#     |-pcd0647cneg.txt
#     |-pcd0645.txt
#     |-pcd0690cpos.txt
#     |-pcd0669cneg.txt
#     |-pcd0634.txt
#     |-pcd0624r.png
#     |-pcd0601r.png
#     |-pcd0645cpos.txt
#     |-pcd0687d.tiff
#     |-pcd0637d.tiff
#     |-pcd0647.txt
#     |-pcd0687cpos.txt
#     |-pcd0677cneg.txt
#     |-pcd0646.txt
#     |-pcd0658d.tiff
#     |-pcd0605r.png
#     |-pcd0674r.png
#     |-pcd0656.txt
#     |-pcd0607cneg.txt
#     |-pcd0667r.png
#     |-pcd0684.txt
#     |-pcd0648cneg.txt
#     |-pcd0640d.tiff
#     |-pcd0604cpos.txt
#     |-pcd0616cneg.txt
#     |-pcd0619cneg.txt
#     |-pcd0679cpos.txt
#     |-pcd0634cneg.txt
#     |-pcd0685.txt
#     |-pcd0616.txt
#     |-pcd0603cneg.txt
#     |-pcd0651cpos.txt
#     |-pcd0672cpos.txt
#     |-pcd0611d.tiff
#     |-pcd0672r.png
#     |-pcd0678.txt
#     |-pcd0611.txt
#     |-pcd0660d.tiff
#     |-pcd0626d.tiff
#     |-pcd0648d.tiff
#     |-pcd0619r.png
#   |-../cornell/05
#     |-pcd0593cneg.txt
#     |-pcd0521cneg.txt
#     |-pcd0566cpos.txt
#     |-pcd0571cneg.txt
#     |-pcd0525d.tiff
#     |-pcd0574d.tiff
#     |-pcd0591cneg.txt
#     |-pcd0523.txt
#     |-pcd0536.txt
#     |-pcd0578cpos.txt
#     |-pcd0597.txt
#     |-pcd0533.txt
#     |-pcd0524d.tiff
#     |-pcd0540r.png
#     |-pcd0582cpos.txt
#     |-pcd0581.txt
#     |-pcd0522d.tiff
#     |-pcd0553r.png
#     |-pcd0587cneg.txt
#     |-pcd0584d.tiff
#     |-pcd0517cneg.txt
#     |-pcd0517cpos.txt
#     |-pcd0577cneg.txt
#     |-pcd0559cpos.txt
#     |-pcd0584.txt
#     |-pcd0502cpos.txt
#     |-pcd0597cneg.txt
#     |-pcd0542d.tiff
#     |-pcd0592d.tiff
#     |-pcd0566d.tiff
#     |-pcd0507.txt
#     |-pcd0596cpos.txt
#     |-pcd0519cpos.txt
#     |-pcd0548cpos.txt
#     |-pcd0504r.png
#     |-pcd0503.txt
#     |-pcd0595d.tiff
#     |-pcd0569.txt
#     |-pcd0598.txt
#     |-pcd0502.txt
#     |-pcd0510cpos.txt
#     |-pcd0599cpos.txt
#     |-pcd0526r.png
#     |-pcd0594.txt
#     |-pcd0512cneg.txt
#     |-pcd0594cpos.txt
#     |-pcd0535cpos.txt
#     |-pcd0591d.tiff
#     |-pcd0573cpos.txt
#     |-pcd0560r.png
#     |-pcd0532d.tiff
#     |-pcd0560cpos.txt
#     |-pcd0549cpos.txt
#     |-pcd0515.txt
#     |-pcd0585cneg.txt
#     |-pcd0520cpos.txt
#     |-pcd0537.txt
#     |-pcd0535cneg.txt
#     |-pcd0539cpos.txt
#     |-pcd0599.txt
#     |-pcd0546cneg.txt
#     |-pcd0581d.tiff
#     |-pcd0512.txt
#     |-pcd0511cneg.txt
#     |-pcd0560.txt
#     |-pcd0575.txt
#     |-pcd0561cpos.txt
#     |-pcd0531cneg.txt
#     |-pcd0582r.png
#     |-pcd0580.txt
#     |-pcd0503r.png
#     |-pcd0547d.tiff
#     |-pcd0520.txt
#     |-pcd0544cpos.txt
#     |-pcd0569r.png
#     |-pcd0596d.tiff
#     |-pcd0590r.png
#     |-pcd0570r.png
#     |-pcd0586d.tiff
#     |-pcd0506r.png
#     |-pcd0579cneg.txt
#     |-pcd0571cpos.txt
#     |-pcd0566.txt
#     |-pcd0524cneg.txt
#     |-pcd0514cpos.txt
#     |-pcd0516cneg.txt
#     |-pcd0522cpos.txt
#     |-pcd0593cpos.txt
#     |-pcd0513r.png
#     |-pcd0508cneg.txt
#     |-pcd0534cneg.txt
#     |-pcd0540cneg.txt
#     |-pcd0592.txt
#     |-pcd0555cpos.txt
#     |-pcd0500cneg.txt
#     |-pcd0548.txt
#     |-pcd0543cneg.txt
#     |-pcd0575r.png
#     |-pcd0533cneg.txt
#     |-pcd0563cpos.txt
#     |-pcd0544.txt
#     |-pcd0574cneg.txt
#     |-pcd0597d.tiff
#     |-pcd0574cpos.txt
#     |-pcd0587d.tiff
#     |-pcd0556r.png
#     |-pcd0547cneg.txt
#     |-pcd0559r.png
#     |-pcd0515cneg.txt
#     |-pcd0565r.png
#     |-pcd0552.txt
#     |-pcd0578r.png
#     |-pcd0573d.tiff
#     |-pcd0588cpos.txt
#     |-pcd0534cpos.txt
#     |-pcd0528.txt
#     |-pcd0520cneg.txt
#     |-pcd0596cneg.txt
# ...
#     |-pcd0368d.tiff
#     |-pcd0363.txt
#     |-pcd0371.txt
#     |-pcd0384cneg.txt
#     |-pcd0362r.png
#     |-pcd0385d.tiff
#     |-pcd0320cneg.txt
#     |-pcd0368cneg.txt
#     |-pcd0380cpos.txt
#     |-pcd0366cneg.txt
#     |-pcd0307d.tiff
#     |-pcd0338r.png
#     |-pcd0382d.tiff
#     |-pcd0333.txt
#     |-pcd0394cpos.txt
#     |-pcd0321r.png
#     |-pcd0322cneg.txt
#     |-pcd0335cpos.txt
#     |-pcd0383.txt
#     |-pcd0326cpos.txt
#     |-pcd0336cneg.txt
#     |-pcd0360cpos.txt
#     |-pcd0379cpos.txt
#     |-pcd0355r.png
#     |-pcd0306cneg.txt
#     |-pcd0346r.png
#     |-pcd0353cneg.txt
#     |-pcd0301cneg.txt
#     |-pcd0327r.png
#     |-pcd0337r.png
#     |-pcd0331cpos.txt
#     |-pcd0308cneg.txt
#     |-pcd0390cneg.txt
#     |-pcd0386d.tiff
#     |-pcd0385r.png
#     |-pcd0337.txt
#     |-pcd0387.txt
#     |-pcd0309r.png
#     |-pcd0390r.png
#     |-pcd0327cneg.txt
#     |-pcd0374.txt
#     |-pcd0389cpos.txt
#     |-pcd0357r.png
#     |-pcd0378cpos.txt
#     |-pcd0332cpos.txt
#     |-pcd0395r.png
#     |-pcd0387cpos.txt
#     |-pcd0361cneg.txt
#     |-pcd0329d.tiff
#     |-pcd0336cpos.txt
#     |-pcd0368.txt
#     |-pcd0341cpos.txt
#     |-pcd0393.txt
#     |-pcd0356.txt
#     |-pcd0315cpos.txt
#     |-pcd0307cneg.txt
#     |-pcd0302r.png
#     |-pcd0376d.tiff
#     |-pcd0361d.tiff
#     |-pcd0325cpos.txt
#     |-pcd0358cneg.txt
#     |-pcd0325r.png
#     |-pcd0350.txt
#     |-pcd0335.txt
#     |-pcd0300cneg.txt
#     |-pcd0379d.tiff
#     |-pcd0388d.tiff
#     |-pcd0390cpos.txt
#     |-pcd0377cneg.txt
#     |-pcd0376cneg.txt
#     |-pcd0354cpos.txt
#     |-pcd0385.txt
#     |-pcd0362.txt
#     |-pcd0337d.tiff
#     |-pcd0331r.png
#     |-pcd0354d.tiff
#     |-pcd0371cneg.txt
#     |-pcd0349d.tiff
#     |-pcd0391cpos.txt
#     |-pcd0362cpos.txt
#     |-pcd0328cneg.txt
#     |-pcd0389d.tiff
#     |-pcd0345r.png
#     |-pcd0334d.tiff
#     |-pcd0342.txt
#     |-pcd0319cneg.txt
#     |-pcd0373cpos.txt
#     |-pcd0375cneg.txt
#     |-pcd0307r.png
#     |-pcd0302d.tiff
#     |-pcd0385cpos.txt
#     |-pcd0318d.tiff
#     |-pcd0365cneg.txt
#     |-pcd0397r.png
#     |-pcd0370cneg.txt
#     |-pcd0386cneg.txt
#     |-pcd0308d.tiff
#     |-pcd0318cneg.txt
#     |-pcd0371d.tiff
#     |-pcd0334r.png
#     |-pcd0363cpos.txt
#     |-pcd0317d.tiff
#     |-pcd0375cpos.txt
#     |-pcd0308r.png
#     |-pcd0346d.tiff
#     |-pcd0393d.tiff
#     |-pcd0374r.png
#     |-pcd0342cpos.txt
#     |-pcd0361cpos.txt
#     |-pcd0320d.tiff
#     |-pcd0341.txt
#     |-pcd0358d.tiff
#     |-pcd0335d.tiff
#     |-pcd0386.txt
#     |-pcd0326d.tiff
#     |-pcd0356cpos.txt
#     |-pcd0309cneg.txt
#     |-pcd0394r.png
#     |-pcd0346cpos.txt
#     |-pcd0326r.png
#     |-pcd0342r.png
#     |-pcd0383d.tiff
#     |-pcd0357d.tiff
#     |-pcd0341r.png
#     |-pcd0321d.tiff
#     |-pcd0378r.png
#     |-pcd0396r.png
#     |-pcd0348.txt
#     |-pcd0316.txt
#     |-pcd0311.txt
#     |-pcd0391.txt
#     |-pcd0355cneg.txt
#     |-pcd0349.txt
#     |-pcd0333cneg.txt
#     |-pcd0311cneg.txt
#     |-pcd0357cpos.txt
#     |-pcd0332.txt
#     |-pcd0300.txt
#     |-pcd0339.txt
#     |-pcd0392r.png
#     |-pcd0354.txt
#     |-pcd0315d.tiff
#     |-pcd0350cneg.txt
#     |-pcd0353.txt
#     |-pcd0387cneg.txt
#     |-pcd0304r.png
#     |-pcd0343r.png
#     |-pcd0376.txt
#     |-pcd0302cpos.txt
#     |-pcd0399r.png
#     |-pcd0370d.tiff
#     |-pcd0305cpos.txt
#     |-pcd0329cpos.txt
#     |-pcd0367r.png
#     |-pcd0392cneg.txt
#     |-pcd0301.txt
#     |-pcd0331d.tiff
#     |-pcd0339cpos.txt
#     |-pcd0383r.png
#     |-pcd0373r.png
#     |-pcd0338.txt
#     |-pcd0353d.tiff
#     |-pcd0323r.png
#     |-pcd0332cneg.txt
#     |-pcd0319d.tiff
#     |-pcd0321cneg.txt
#     |-pcd0351r.png
#     |-pcd0387r.png
#     |-pcd0329r.png
#     |-pcd0300r.png
#     |-pcd0375.txt
#     |-pcd0380cneg.txt
#     |-pcd0311r.png
#     |-pcd0351.txt
#     |-pcd0385cneg.txt
#     |-pcd0310r.png
#     |-pcd0377d.tiff
#     |-pcd0369d.tiff
#     |-pcd0308.txt
#     |-pcd0315r.png
#     |-pcd0361r.png
#     |-pcd0334cpos.txt
#     |-pcd0352cpos.txt
#     |-pcd0357cneg.txt
#     |-pcd0362d.tiff
#     |-pcd0314r.png
#     |-pcd0317r.png
#     |-pcd0359.txt
#     |-pcd0314cneg.txt
#     |-pcd0369.txt
#     |-pcd0327.txt
#     |-pcd0319.txt
#     |-pcd0348cpos.txt
#     |-pcd0314.txt
#     |-pcd0319cpos.txt
#     |-pcd0365cpos.txt
#     |-pcd0322r.png
#     |-pcd0322d.tiff
#     |-pcd0340r.png
#     |-pcd0375r.png
#     |-pcd0382cneg.txt
#     |-pcd0397cpos.txt
#     |-pcd0363cneg.txt
#     |-pcd0372d.tiff
#     |-pcd0354cneg.txt
#     |-pcd0358.txt
#     |-pcd0363r.png
#     |-pcd0332r.png
#     |-pcd0349r.png
#     |-pcd0373cneg.txt
#     |-pcd0376r.png
#     |-pcd0317cpos.txt
#     |-pcd0359r.png
#     |-pcd0312d.tiff
#     |-pcd0355.txt
#     |-pcd0388cpos.txt
#     |-pcd0312cpos.txt
#     |-pcd0375d.tiff
#     |-pcd0352.txt
#     |-pcd0382.txt
#     |-pcd0356d.tiff
#     |-pcd0342cneg.txt
#     |-pcd0323cneg.txt
#     |-pcd0328d.tiff
#     |-pcd0323.txt
#     |-pcd0373d.tiff
#     |-pcd0368cpos.txt
#     |-pcd0389r.png
#     |-pcd0329cneg.txt
#     |-pcd0342d.tiff
#     |-pcd0368r.png
#     |-pcd0369cneg.txt
#     |-pcd0302.txt
#     |-pcd0305d.tiff
#     |-pcd0315.txt
#     |-pcd0344.txt
#     |-pcd0324d.tiff
#     |-pcd0370cpos.txt
#     |-pcd0369r.png
#     |-pcd0347.txt
#     |-pcd0337cneg.txt
#     |-pcd0321cpos.txt
#     |-pcd0380d.tiff
#     |-pcd0305.txt
#     |-pcd0311cpos.txt
#     |-pcd0343d.tiff
#     |-pcd0345d.tiff
#     |-pcd0322.txt
#     |-pcd0330d.tiff
#     |-pcd0324.txt
#     |-pcd0343cneg.txt
#     |-pcd0393cneg.txt
#     |-pcd0372cneg.txt
#     |-pcd0374cneg.txt
#     |-pcd0389cneg.txt
#     |-pcd0306d.tiff
#     |-pcd0313r.png
#     |-pcd0396.txt
#     |-pcd0301cpos.txt
#     |-pcd0321.txt
#     |-pcd0313cneg.txt
#     |-pcd0324r.png
#     |-pcd0349cpos.txt
#     |-pcd0364r.png
#     |-pcd0365d.tiff
#     |-pcd0398cneg.txt
#     |-pcd0397.txt
#     |-pcd0310cpos.txt
#     |-pcd0344d.tiff
#     |-pcd0384cpos.txt
#     |-pcd0326.txt
#     |-pcd0333cpos.txt
#     |-pcd0360d.tiff
#     |-pcd0341cneg.txt
#     |-pcd0394d.tiff
#     |-pcd0346.txt
#     |-pcd0335r.png
#     |-pcd0359cneg.txt
#     |-pcd0371r.png
#   |-../cornell/04
#     |-pcd0481d.tiff
#     |-pcd0426.txt
#     |-pcd0442r.png
#     |-pcd0471cneg.txt
#     |-pcd0459cpos.txt
#     |-pcd0483cneg.txt
#     |-pcd0462d.tiff
#     |-pcd0471.txt
#     |-pcd0485.txt
#     |-pcd0448r.png
#     |-pcd0419r.png
#     |-pcd0451cneg.txt
#     |-pcd0466r.png
#     |-pcd0401cpos.txt
#     |-pcd0421r.png
#     |-pcd0433.txt
#     |-pcd0426d.tiff
#     |-pcd0415.txt
#     |-pcd0480d.tiff
#     |-pcd0424cneg.txt
#     |-pcd0477.txt
#     |-pcd0436cneg.txt
#     |-pcd0417cneg.txt
#     |-pcd0411d.tiff
#     |-pcd0401.txt
#     |-pcd0450cpos.txt
#     |-pcd0457r.png
#     |-pcd0431r.png
#     |-pcd0413.txt
#     |-pcd0428cneg.txt
#     |-pcd0449d.tiff
#     |-pcd0437r.png
#     |-pcd0472.txt
#     |-pcd0470.txt
#     |-pcd0405r.png
#     |-pcd0414.txt
#     |-pcd0439d.tiff
#     |-pcd0476d.tiff
#     |-pcd0411.txt
#     |-pcd0446cpos.txt
#     |-pcd0462.txt
#     |-pcd0437cneg.txt
#     |-pcd0407cneg.txt
#     |-pcd0498cneg.txt
#     |-pcd0468cneg.txt
#     |-pcd0494r.png
#     |-pcd0441cneg.txt
#     |-pcd0424cpos.txt
#     |-pcd0470d.tiff
#     |-pcd0486cneg.txt
#     |-pcd0488cpos.txt
#     |-pcd0435d.tiff
#     |-pcd0464d.tiff
#     |-pcd0444d.tiff
#     |-pcd0496d.tiff
#     |-pcd0452r.png
#     |-pcd0463d.tiff
#     |-pcd0488d.tiff
#     |-pcd0404cpos.txt
#     |-pcd0454d.tiff
#     |-pcd0414r.png
#     |-pcd0429.txt
#     |-pcd0482cpos.txt
#     |-pcd0459d.tiff
#     |-pcd0477cneg.txt
#     |-pcd0494cpos.txt
#     |-pcd0433cpos.txt
#     |-pcd0450.txt
#     |-pcd0476.txt
#     |-pcd0402cneg.txt
#     |-pcd0423.txt
#     |-pcd0464r.png
#     |-pcd0453cpos.txt
#     |-pcd0497r.png
#     |-pcd0488cneg.txt
#     |-pcd0460r.png
#     |-pcd0478cneg.txt
#     |-pcd0466.txt
#     |-pcd0487d.tiff
#     |-pcd0486cpos.txt
#     |-pcd0446d.tiff
#     |-pcd0457cneg.txt
#     |-pcd0492cpos.txt
#     |-pcd0439cneg.txt
#     |-pcd0486.txt
#     |-pcd0484r.png
#     |-pcd0472cneg.txt
#     |-pcd0495cneg.txt
#     |-pcd0458r.png
#     |-pcd0498cpos.txt
#     |-pcd0445cpos.txt
#     |-pcd0445d.tiff
#     |-pcd0440cneg.txt
#     |-pcd0443cpos.txt
#     |-pcd0460cpos.txt
#     |-pcd0489.txt
#     |-pcd0401d.tiff
#     |-pcd0402.txt
#     |-pcd0492.txt
#     |-pcd0475cneg.txt
#     |-pcd0417.txt
#     |-pcd0448cpos.txt
#     |-pcd0418r.png
#     |-pcd0471cpos.txt
#     |-pcd0474cpos.txt
#     |-pcd0451r.png
#     |-pcd0470r.png
#     |-pcd0448d.tiff
#     |-pcd0416cneg.txt
#     |-pcd0430.txt
#     |-pcd0474d.tiff
#     |-pcd0413cneg.txt
#     |-pcd0449cpos.txt
#     |-pcd0432cneg.txt
#     |-pcd0471d.tiff
#     |-pcd0499r.png
#     |-pcd0412d.tiff
#     |-pcd0435.txt
#     |-pcd0444cneg.txt
#     |-pcd0475d.tiff
#     |-pcd0403cneg.txt
#     |-pcd0403d.tiff
#     |-pcd0491d.tiff
#     |-pcd0478r.png
#     |-pcd0489cneg.txt
#     |-pcd0471r.png
#     |-pcd0410cneg.txt
#     |-pcd0413d.tiff
#     |-pcd0452cpos.txt
#     |-pcd0456d.tiff
#     |-pcd0403cpos.txt
#     |-pcd0412cpos.txt
#     |-pcd0428cpos.txt
#     |-pcd0495r.png
#     |-pcd0420cpos.txt
#     |-pcd0489r.png
#     |-pcd0442cpos.txt
#     |-pcd0491r.png
#     |-pcd0485cpos.txt
#     |-pcd0465r.png
#     |-pcd0473r.png
#     |-pcd0486d.tiff
#     |-pcd0408r.png
#     |-pcd0417cpos.txt
#     |-pcd0448.txt
#     |-pcd0478d.tiff
#     |-pcd0438d.tiff
#     |-pcd0490d.tiff
#     |-pcd0440cpos.txt
#     |-pcd0421.txt
#     |-pcd0420r.png
#     |-pcd0434r.png
#     |-pcd0487r.png
#     |-pcd0451cpos.txt
#     |-pcd0484d.tiff
#     |-pcd0410cpos.txt
#     |-pcd0403.txt
#     |-pcd0409r.png
#     |-pcd0432r.png
#     |-pcd0403r.png
#     |-pcd0407cpos.txt
#     |-pcd0443.txt
#     |-pcd0459cneg.txt
#     |-pcd0487.txt
#     |-pcd0432.txt
#     |-pcd0434.txt
#     |-pcd0491cpos.txt
#     |-pcd0443d.tiff
#     |-pcd0477cpos.txt
#     |-pcd0474cneg.txt
#     |-pcd0454cneg.txt
#     |-pcd0492r.png
#     |-pcd0456r.png
#     |-pcd0478cpos.txt
#     |-pcd0416r.png
#     |-pcd0447cneg.txt
#     |-pcd0422d.tiff
#     |-pcd0436d.tiff
#     |-pcd0468r.png
#     |-pcd0458cpos.txt
#     |-pcd0427r.png
#     |-pcd0483cpos.txt
#     |-pcd0479cpos.txt
#     |-pcd0450d.tiff
#     |-pcd0466d.tiff
#     |-pcd0432cpos.txt
#     |-pcd0414cpos.txt
#     |-pcd0446.txt
#     |-pcd0457d.tiff
#     |-pcd0453cneg.txt
#     |-pcd0436cpos.txt
#     |-pcd0432d.tiff
#     |-pcd0431cpos.txt
#     |-pcd0416.txt
#     |-pcd0422cneg.txt
#     |-pcd0466cpos.txt
#     |-pcd0480cpos.txt
#     |-pcd0450r.png
#     |-pcd0431d.tiff
#     |-pcd0426r.png
#     |-pcd0427.txt
#     |-pcd0497cneg.txt
#     |-pcd0412cneg.txt
#     |-pcd0427d.tiff
#     |-pcd0409cneg.txt
#     |-pcd0409cpos.txt
#     |-pcd0441cpos.txt
#     |-pcd0462r.png
#     |-pcd0425d.tiff
#     |-pcd0477d.tiff
#     |-pcd0469d.tiff
#     |-pcd0405cpos.txt
#     |-pcd0443cneg.txt
#     |-pcd0438r.png
#     |-pcd0437.txt
#     |-pcd0405.txt
#     |-pcd0496.txt
#     |-pcd0423d.tiff
#     |-pcd0430cneg.txt
#     |-pcd0434cneg.txt
#     |-pcd0418cpos.txt
#     |-pcd0461cneg.txt
#     |-pcd0473d.tiff
#     |-pcd0469.txt
#     |-pcd0484.txt
#     |-pcd0421cpos.txt
#     |-pcd0405cneg.txt
#     |-pcd0473cneg.txt
#     |-pcd0411cpos.txt
#     |-pcd0422r.png
#     |-pcd0476cneg.txt
#     |-pcd0422.txt
#     |-pcd0456.txt
#     |-pcd0434d.tiff
#     |-pcd0444r.png
#     |-pcd0481cpos.txt
#     |-pcd0445r.png
#     |-pcd0496cneg.txt
#     |-pcd0435r.png
#     |-pcd0473cpos.txt
#     |-pcd0447cpos.txt
#     |-pcd0464.txt
#     |-pcd0464cpos.txt
#     |-pcd0497d.tiff
#     |-pcd0433r.png
#     |-pcd0451d.tiff
#     |-pcd0499d.tiff
#     |-pcd0420d.tiff
#     |-pcd0482r.png
#     |-pcd0415d.tiff
#     |-pcd0426cneg.txt
#     |-pcd0414cneg.txt
#     |-pcd0481r.png
#     |-pcd0488.txt
#     |-pcd0454r.png
#     |-pcd0474.txt
#     |-pcd0496cpos.txt
#     |-pcd0402r.png
#     |-pcd0408cneg.txt
#     |-pcd0415cneg.txt
#     |-pcd0498.txt
#     |-pcd0468.txt
#     |-pcd0430cpos.txt
#     |-pcd0408.txt
#     |-pcd0407r.png
#     |-pcd0453r.png
#     |-pcd0433d.tiff
#     |-pcd0476cpos.txt
#     |-pcd0458d.tiff
#     |-pcd0454.txt
#     |-pcd0442cneg.txt
#     |-pcd0482d.tiff
#     |-pcd0451.txt
#     |-pcd0456cneg.txt
#     |-pcd0460.txt
#     |-pcd0483.txt
#     |-pcd0459r.png
#     |-pcd0410r.png
#     |-pcd0420cneg.txt
#     |-pcd0401cneg.txt
#     |-pcd0490.txt
#     |-pcd0479.txt
#     |-pcd0484cneg.txt
#     |-pcd0402cpos.txt
#     |-pcd0479r.png
#     |-pcd0469r.png
#     |-pcd0452d.tiff
#     |-pcd0421d.tiff
#     |-pcd0427cpos.txt
#     |-pcd0475cpos.txt
#     |-pcd0423r.png
#     |-pcd0495cpos.txt
#     |-pcd0404.txt
#     |-pcd0470cpos.txt
#     |-pcd0475.txt
#     |-pcd0428r.png
#     |-pcd0418.txt
#     |-pcd0453.txt
#     |-pcd0487cpos.txt
#     |-pcd0449r.png
#     |-pcd0408d.tiff
#     |-pcd0424d.tiff
#     |-pcd0417d.tiff
#     |-pcd0460d.tiff
#     |-pcd0480.txt
#     |-pcd0489cpos.txt
#     |-pcd0427cneg.txt
#     |-pcd0443r.png
#     |-pcd0423cneg.txt
#     |-pcd0472r.png
#     |-pcd0417r.png
#     |-pcd0435cpos.txt
#     |-pcd0440r.png
#     |-pcd0412r.png
#     |-pcd0441.txt
#     |-pcd0437cpos.txt
#     |-pcd0454cpos.txt
#     |-pcd0413r.png
#     |-pcd0457cpos.txt
#     |-pcd0459.txt
#     |-pcd0428.txt
#     |-pcd0455r.png
#     |-pcd0404cneg.txt
#     |-pcd0465cpos.txt
#     |-pcd0479d.tiff
#     |-pcd0467d.tiff
#     |-pcd0446r.png
#     |-pcd0463r.png
#     |-pcd0425r.png
#     |-pcd0445cneg.txt
#     |-pcd0404d.tiff
#     |-pcd0465cneg.txt
#     |-pcd0465.txt
#     |-pcd0420.txt
#     |-pcd0444cpos.txt
#     |-pcd0461.txt
#     |-pcd0418cneg.txt
#     |-pcd0461r.png
#     |-pcd0461cpos.txt
#     |-pcd0485cneg.txt
#     |-pcd0489d.tiff
#     |-pcd0439cpos.txt
#     |-pcd0494d.tiff
#     |-pcd0455cneg.txt
#     |-pcd0472d.tiff
#     |-pcd0463cpos.txt
#     |-pcd0497.txt
#     |-pcd0453d.tiff
#     |-pcd0447.txt
#     |-pcd0478.txt
#     |-pcd0483d.tiff
#     |-pcd0458.txt
#     |-pcd0408cpos.txt
#     |-pcd0438.txt
#     |-pcd0490cneg.txt
#     |-pcd0424.txt
#     |-pcd0488r.png
#     |-pcd0495d.tiff
#     |-pcd0474r.png
#     |-pcd0493cpos.txt
#     |-pcd0469cneg.txt
#     |-pcd0481cneg.txt
#     |-pcd0429d.tiff
#     |-pcd0483r.png
#     |-pcd0493cneg.txt
#     |-pcd0477r.png
#     |-pcd0491.txt
#     |-pcd0486r.png
#     |-pcd0430d.tiff
#     |-pcd0465d.tiff
#     |-pcd0447d.tiff
#     |-pcd0499.txt
#     |-pcd0485r.png
#     |-pcd0470cneg.txt
#     |-pcd0484cpos.txt
#     |-pcd0400d.tiff
#     |-pcd0438cneg.txt
#     |-pcd0431.txt
#     |-pcd0475r.png
#     |-pcd0498r.png
#     |-pcd0406r.png
#     |-pcd0455d.tiff
#     |-pcd0400cpos.txt
#     |-pcd0415cpos.txt
#     |-pcd0400r.png
#     |-pcd0419cpos.txt
#     |-pcd0419cneg.txt
#     |-pcd0448cneg.txt
#     |-pcd0411r.png
#     |-pcd0436.txt
#     |-pcd0482.txt
#     |-pcd0409.txt
#     |-pcd0467.txt
#     |-pcd0416cpos.txt
#     |-pcd0405d.tiff
#     |-pcd0400.txt
#     |-pcd0419d.tiff
#     |-pcd0423cpos.txt
#     |-pcd0401r.png
#     |-pcd0456cpos.txt
#     |-pcd0406.txt
#     |-pcd0455.txt
#     |-pcd0481.txt
#     |-pcd0439.txt
#     |-pcd0425cpos.txt
#     |-pcd0407d.tiff
#     |-pcd0449cneg.txt
#     |-pcd0440d.tiff
#     |-pcd0440.txt
#     |-pcd0446cneg.txt
#     |-pcd0485d.tiff
#     |-pcd0463.txt
#     |-pcd0411cneg.txt
#     |-pcd0433cneg.txt
#     |-pcd0458cneg.txt
#     |-pcd0436r.png
#     |-pcd0439r.png
#     |-pcd0410d.tiff
#     |-pcd0468cpos.txt
#     |-pcd0449.txt
#     |-pcd0424r.png
#     |-pcd0482cneg.txt
#     |-pcd0472cpos.txt
#     |-pcd0494cneg.txt
#     |-pcd0425cneg.txt
#     |-pcd0406cneg.txt
#     |-pcd0441d.tiff
#     |-pcd0441r.png
#     |-pcd0495.txt
#     |-pcd0455cpos.txt
#     |-pcd0430r.png
#     |-pcd0407.txt
#     |-pcd0494.txt
#     |-pcd0452.txt
#     |-pcd0409d.tiff
#     |-pcd0460cneg.txt
#     |-pcd0479cneg.txt
#     |-pcd0400cneg.txt
#     |-pcd0457.txt
#     |-pcd0487cneg.txt
#     |-pcd0435cneg.txt
#     |-pcd0466cneg.txt
#     |-pcd0429cpos.txt
#     |-pcd0492d.tiff
#     |-pcd0452cneg.txt
#     |-pcd0425.txt
#     |-pcd0419.txt
#     |-pcd0434cpos.txt
#     |-pcd0468d.tiff
#     |-pcd0444.txt
#     |-pcd0473.txt
#     |-pcd0426cpos.txt
#     |-pcd0469cpos.txt
#     |-pcd0498d.tiff
#     |-pcd0467r.png
#     |-pcd0422cpos.txt
#     |-pcd0429cneg.txt
#     |-pcd0429r.png
#     |-pcd0431cneg.txt
#     |-pcd0462cneg.txt
#     |-pcd0447r.png
#     |-pcd0497cpos.txt
#     |-pcd0406cpos.txt
#     |-pcd0490r.png
#     |-pcd0414d.tiff
#     |-pcd0493d.tiff
#     |-pcd0480r.png
#     |-pcd0445.txt
#     |-pcd0415r.png
#     |-pcd0428d.tiff
#     |-pcd0406d.tiff
#     |-pcd0438cpos.txt
#     |-pcd0480cneg.txt
#     |-pcd0404r.png
#     |-pcd0467cneg.txt
#     |-pcd0412.txt
#     |-pcd0464cneg.txt
#     |-pcd0413cpos.txt
#     |-pcd0476r.png
#     |-pcd0418d.tiff
#     |-pcd0467cpos.txt
#     |-pcd0461d.tiff
#     |-pcd0442d.tiff
#     |-pcd0416d.tiff
#     |-pcd0462cpos.txt
#     |-pcd0499cneg.txt
#     |-pcd0493.txt
#     |-pcd0402d.tiff
#     |-pcd0490cpos.txt
#     |-pcd0410.txt
#     |-pcd0437d.tiff
#     |-pcd0493r.png
#     |-pcd0463cneg.txt
#     |-pcd0421cneg.txt
#     |-pcd0496r.png
#     |-pcd0492cneg.txt
#     |-pcd0450cneg.txt
#     |-pcd0442.txt
#     |-pcd0499cpos.txt
#     |-pcd0491cneg.txt
#   |-../cornell/backgrounds
#     |-pcdb0010r.png
#     |-pcdb0003r.png
#     |-pcdb0005r.png
#     |-pcdb0011r.png
#     |-pcdb0007r.png
#     |-pcdb0013r.png
#     |-pcdb0008r.png
#     |-pcdb0004r.png
#     |-pcdb0006r.png
#     |-pcdb0002r.png
#     |-pcdb0012r.png

# %%
import nvidia.dali.ops as ops
import nvidia.dali.types as types

image_dir = "../cornell/"
batch_size = 8

class SimplePipeline(Pipeline):
    def __init__(self, batch_size, num_threads, device_id):
        super(SimplePipeline, self).__init__(batch_size, num_threads, device_id, seed = 12)
        self.input = ops.FileReader(file_root = image_dir)
        # instead of path to file directory file with pairs image_name image_label_value can be provided
        # self.input = ops.FileReader(file_root = image_dir, file_list = image_dir + '/file_list.txt')
        self.decode = ops.ImageDecoder(device = 'cpu', output_type = types.RGB)

    def define_graph(self):
        jpegs, labels = self.input()
        images = self.decode(jpegs)
        return (images, labels)

# %%
pipe = SimplePipeline(batch_size, 1, 0)
pipe.build()

# %%
test_data_root = os.environ['DALI_EXTRA_PATH']

# MXNet RecordIO
db_folder = os.path.join(test_data_root, 'db', 'recordio/')

# Caffe LMDB
lmdb_folder = os.path.join(test_data_root, 'db', 'lmdb')

# image dir with plain jpeg files
image_dir = "../../data/images"

# TFRecord
tfrecord = os.path.join(test_data_root, 'db', 'tfrecord', 'train')
tfrecord_idx = "idx_files/train.idx"
tfrecord2idx_script = "tfrecord2idx"

N = 8             # number of GPUs
BATCH_SIZE = 128  # batch size per GPU
ITERATIONS = 32
IMAGE_SIZE = 3

# %%
from subprocess import call
import os.path

if not os.path.exists("idx_files"):
    os.mkdir("idx_files")

if not os.path.isfile(tfrecord_idx):
    call([tfrecord2idx_script, tfrecord, tfrecord_idx])

# %%
from nvidia.dali.pipeline import Pipeline
import nvidia.dali.ops as ops
import nvidia.dali.types as types

class CommonPipeline(Pipeline):
    def __init__(self, batch_size, num_threads, device_id):
        super(CommonPipeline, self).__init__(batch_size, num_threads, device_id)

        self.decode = ops.ImageDecoder(device = "mixed", output_type = types.RGB)
        self.resize = ops.Resize(device = "gpu",
                                 interp_type = types.INTERP_LINEAR)
        self.cmn = ops.CropMirrorNormalize(device = "gpu",
                                            dtype = types.FLOAT,
                                            crop = (227, 227),
                                            mean = [128., 128., 128.],
                                            std = [1., 1., 1.])
        self.uniform = ops.Uniform(range = (0.0, 1.0))
        self.resize_rng = ops.Uniform(range = (256, 480))

    def base_define_graph(self, inputs, labels):
        images = self.decode(inputs)
        images = self.resize(images, resize_shorter = self.resize_rng())
        output = self.cmn(images, crop_pos_x = self.uniform(),
                          crop_pos_y = self.uniform())
        return (output, labels)

# %%
#MXNetReader管道
class MXNetReaderPipeline(CommonPipeline):
    def __init__(self, batch_size, num_threads, device_id, num_gpus):
        super(MXNetReaderPipeline, self).__init__(batch_size, num_threads, device_id)
        self.input = ops.MXNetReader(path = [db_folder+"train.rec"], index_path=[db_folder+"train.idx"],
                                     random_shuffle = True, shard_id = device_id, num_shards = num_gpus)

    def define_graph(self):
        images, labels = self.input(name="Reader")
        return self.base_define_graph(images, labels)

# %%
#CaffeRead管道

class CaffeReadPipeline(CommonPipeline):
    def __init__(self, batch_size, num_threads, device_id, num_gpus):
        super(CaffeReadPipeline, self).__init__(batch_size, num_threads, device_id)
        self.input = ops.CaffeReader(path = lmdb_folder,
                                     random_shuffle = True, shard_id = device_id, num_shards = num_gpus)

    def define_graph(self):
        images, labels = self.input(name="Reader")
        return self.base_define_graph(images, labels)

# %%
#FileReadPipeline

class FileReadPipeline(CommonPipeline):
        def __init__(self, batch_size, num_threads, device_id, num_gpus):
            super(FileReadPipeline, self).__init__(batch_size, num_threads, device_id)
            self.input = ops.FileReader(file_root = image_dir)

        def define_graph(self):
            images, labels = self.input(name="Reader")
            return self.base_define_graph(images, labels)

# %%
#TFRecordPipeline
import nvidia.dali.tfrecord as tfrec

class TFRecordPipeline(CommonPipeline):
    def __init__(self, batch_size, num_threads, device_id, num_gpus):
        super(TFRecordPipeline, self).__init__(batch_size, num_threads, device_id)
        self.input = ops.TFRecordReader(path = tfrecord,
                                        index_path = tfrecord_idx,
                                        features = {"image/encoded" : tfrec.FixedLenFeature((), tfrec.string, ""),
                                                    "image/class/label": tfrec.FixedLenFeature([1], tfrec.int64,  -1)
                                        })

    def define_graph(self):
        inputs = self.input(name="Reader")
        images = inputs["image/encoded"]
        labels = inputs["image/class/label"]
        return self.base_define_graph(images, labels)

# %%
import numpy as np
from nvidia.dali.plugin.pytorch import DALIGenericIterator

pipe_types = [
              [CaffeReadPipeline, (0, 999)],
              [FileReadPipeline, (0, 1)],
              [TFRecordPipeline, (1, 1000)]]
for pipe_t in pipe_types:
    pipe_name, label_range = pipe_t
    print ("RUN: "  + pipe_name.__name__)
    pipes = [pipe_name(batch_size=BATCH_SIZE, num_threads=2, device_id = device_id, num_gpus = N) for device_id in range(N)]
    pipes[0].build()
    dali_iter = DALIGenericIterator(pipes, ['data', 'label'], pipes[0].epoch_size("Reader"))

    for i, data in enumerate(dali_iter):
        if i >= ITERATIONS:
            break
        # Testing correctness of labels
        for d in data:
            label = d["label"]
            image = d["data"]
            ## labels need to be integers
            assert(np.equal(np.mod(label, 1), 0).all())
            ## labels need to be in range pipe_name[2]
            assert((label >= label_range[0]).all())
            assert((label <= label_range[1]).all())
    print("OK : " + pipe_name.__name__)
# Out:
# RUN: CaffeReadPipeline
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-16-3d8d543db399> in <module>
#       9     print ("RUN: "  + pipe_name.__name__)
#      10     pipes = [pipe_name(batch_size=BATCH_SIZE, num_threads=2, device_id = device_id, num_gpus = N) for device_id in range(N)]
# ---> 11     pipes[0].build()
#      12     dali_iter = DALIGenericIterator(pipes, ['data', 'label'], pipes[0].epoch_size("Reader"))
#      13
#
# ~/anaconda3/envs/gg_cnn/lib/python3.6/site-packages/nvidia/dali/pipeline.py in build(self, define_graph)
#     477             self._prepare_graph(define_graph)
#     478
# --> 479         self._pipe.Build(self._names_and_devices)
#     480         self._built = True
#     481
#
# RuntimeError: Critical error when building pipeline:
# Error when constructing operator: CaffeReader encountered:
# [/opt/dali/dali/operators/reader/loader/lmdb.h:52] Assert on "mdb_env_open(mdb_env_, path.c_str(), mdb_flags, 0664) == 0" failed: LMDB Error: No such file or directory, with file: /home/ldh/Documents/github_repository/DALI_extra:/db/lmdb
# Stacktrace (100 entries):
# [frame 0]: /home/ldh/anaconda3/envs/gg_cnn/lib/python3.6/site-packages/nvidia/dali/libdali_operators.so(+0x3cf8ee) [0x7f283e7218ee]
# [frame 1]: /home/ldh/anaconda3/envs/gg_cnn/lib/python3.6/site-packages/nvidia/dali/libdali_operators.so(+0x182a83b) [0x7f283fb7c83b]
# [frame 2]: /home/ldh/anaconda3/envs/gg_cnn/lib/python3.6/site-packages/nvidia/dali/libdali_operators.so(+0x1830cc9) [0x7f283fb82cc9]
# [frame 3]: /home/ldh/anaconda3/envs/gg_cnn/lib/python3.6/site-packages/nvidia/dali/libdali_operators.so(std::_Function_handler<std::unique_ptr<dali::OperatorBase, std::default_delete<dali::OperatorBase> > (dali::OpSpec const&), std::unique_ptr<dali::OperatorBase, std::default_delete<dali::OperatorBase> > (*)(dali::OpSpec const&)>::_M_invoke(std::_Any_data const&, dali::OpSpec const&)+0xc) [0x7f283e7196bc]
# [frame 4]: /home/ldh/anaconda3/envs/gg_cnn/lib/python3.6/site-packages/nvidia/dali/libdali.so(+0x18b9e4) [0x7f28652579e4]
# [frame 5]: /home/ldh/anaconda3/envs/gg_cnn/lib/python3.6/site-packages/nvidia/dali/libdali.so(dali::InstantiateOperator(dali::OpSpec const&)+0x264) [0x7f2865257324]
# [frame 6]: /home/ldh/anaconda3/envs/gg_cnn/lib/python3.6/site-packages/nvidia/dali/libdali.so(dali::OpGraph::InstantiateOperators()+0xa2) [0x7f2865214352]
# [frame 7]: /home/ldh/anaconda3/envs/gg_cnn/lib/python3.6/site-packages/nvidia/dali/libdali.so(dali::Pipeline::Build(std::vector<std::pair<std::string, std::string>, std::allocator<std::pair<std::string, std::string> > >)+0x9e0) [0x7f2865270fb0]
# [frame 8]: /home/ldh/anaconda3/envs/gg_cnn/lib/python3.6/site-packages/nvidia/dali/backend_impl.cpython-36m-x86_64-linux-gnu.so(+0x444af) [0x7f28742ab4af]
# [frame 9]: /home/ldh/anaconda3/envs/gg_cnn/lib/python3.6/site-packages/nvidia/dali/backend_impl.cpython-36m-x86_64-linux-gnu.so(+0x90bb4) [0x7f28742f7bb4]
# [frame 10]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyCFunction_FastCallDict+0x154) [0x556c364ea304]
# [frame 11]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x199c5e) [0x556c36571c5e]
# [frame 12]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyEval_EvalFrameDefault+0x30a) [0x556c3659481a]
# [frame 13]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x192f26) [0x556c3656af26]
# [frame 14]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x193f31) [0x556c3656bf31]
# [frame 15]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x199be5) [0x556c36571be5]
# [frame 16]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyEval_EvalFrameDefault+0x30a) [0x556c3659481a]
# [frame 17]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(PyEval_EvalCodeEx+0x329) [0x556c3656ca49]
# [frame 18]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(PyEval_EvalCode+0x1c) [0x556c3656d7ec]
# [frame 19]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x1ba227) [0x556c36592227]
# [frame 20]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyCFunction_FastCallDict+0x91) [0x556c364ea241]
# [frame 21]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x199b0c) [0x556c36571b0c]
# [frame 22]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyEval_EvalFrameDefault+0x30a) [0x556c3659481a]
# [frame 23]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyGen_Send+0x256) [0x556c36574bc6]
# [frame 24]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyEval_EvalFrameDefault+0x1445) [0x556c36595955]
# [frame 25]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyGen_Send+0x256) [0x556c36574bc6]
# [frame 26]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyEval_EvalFrameDefault+0x1445) [0x556c36595955]
# [frame 27]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyGen_Send+0x256) [0x556c36574bc6]
# [frame 28]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyCFunction_FastCallDict+0x115) [0x556c364ea2c5]
# [frame 29]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x199b0c) [0x556c36571b0c]
# [frame 30]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyEval_EvalFrameDefault+0x30a) [0x556c3659481a]
# [frame 31]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x193cfb) [0x556c3656bcfb]
# [frame 32]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x199be5) [0x556c36571be5]
# [frame 33]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyEval_EvalFrameDefault+0x30a) [0x556c3659481a]
# [frame 34]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x193cfb) [0x556c3656bcfb]
# [frame 35]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x199be5) [0x556c36571be5]
# [frame 36]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyEval_EvalFrameDefault+0x30a) [0x556c3659481a]
# [frame 37]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x192f26) [0x556c3656af26]
# [frame 38]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyFunction_FastCallDict+0x3d8) [0x556c3656c628]
# [frame 39]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyObject_FastCallDict+0x26f) [0x556c364ea6cf]
# [frame 40]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyObject_Call_Prepend+0x63) [0x556c364ef143]
# [frame 41]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(PyObject_Call+0x3e) [0x556c364ea10e]
# [frame 42]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyEval_EvalFrameDefault+0x1aaf) [0x556c36595fbf]
# [frame 43]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x1931f6) [0x556c3656b1f6]
# [frame 44]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x193f31) [0x556c3656bf31]
# [frame 45]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x199be5) [0x556c36571be5]
# [frame 46]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyEval_EvalFrameDefault+0x10c9) [0x556c365955d9]
# [frame 47]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x19c744) [0x556c36574744]
# [frame 48]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyCFunction_FastCallDict+0x91) [0x556c364ea241]
# [frame 49]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x199b0c) [0x556c36571b0c]
# [frame 50]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyEval_EvalFrameDefault+0x30a) [0x556c3659481a]
# [frame 51]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x1931f6) [0x556c3656b1f6]
# [frame 52]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x193f31) [0x556c3656bf31]
# [frame 53]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x199be5) [0x556c36571be5]
# [frame 54]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyEval_EvalFrameDefault+0x30a) [0x556c3659481a]
# [frame 55]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x19c744) [0x556c36574744]
# [frame 56]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyCFunction_FastCallDict+0x91) [0x556c364ea241]
# [frame 57]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x199b0c) [0x556c36571b0c]
# [frame 58]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyEval_EvalFrameDefault+0x30a) [0x556c3659481a]
# [frame 59]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x1931f6) [0x556c3656b1f6]
# [frame 60]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x193f31) [0x556c3656bf31]
# [frame 61]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x199be5) [0x556c36571be5]
# [frame 62]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyEval_EvalFrameDefault+0x30a) [0x556c3659481a]
# [frame 63]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x19c744) [0x556c36574744]
# [frame 64]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyCFunction_FastCallDict+0x91) [0x556c364ea241]
# [frame 65]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x199b0c) [0x556c36571b0c]
# [frame 66]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyEval_EvalFrameDefault+0x30a) [0x556c3659481a]
# [frame 67]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x1931f6) [0x556c3656b1f6]
# [frame 68]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyFunction_FastCallDict+0x1be) [0x556c3656c40e]
# [frame 69]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyObject_FastCallDict+0x26f) [0x556c364ea6cf]
# [frame 70]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyObject_Call_Prepend+0x63) [0x556c364ef143]
# [frame 71]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(PyObject_Call+0x3e) [0x556c364ea10e]
# [frame 72]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyEval_EvalFrameDefault+0x1aaf) [0x556c36595fbf]
# [frame 73]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyGen_Send+0x134) [0x556c36574aa4]
# [frame 74]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyCFunction_FastCallDict+0x115) [0x556c364ea2c5]
# [frame 75]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x199b0c) [0x556c36571b0c]
# [frame 76]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyEval_EvalFrameDefault+0x30a) [0x556c3659481a]
# [frame 77]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x193cfb) [0x556c3656bcfb]
# [frame 78]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x199be5) [0x556c36571be5]
# [frame 79]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyEval_EvalFrameDefault+0x30a) [0x556c3659481a]
# [frame 80]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x1931f6) [0x556c3656b1f6]
# [frame 81]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyFunction_FastCallDict+0x1be) [0x556c3656c40e]
# [frame 82]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyObject_FastCallDict+0x26f) [0x556c364ea6cf]
# [frame 83]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x205c62) [0x556c365ddc62]
# [frame 84]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyObject_FastCallDict+0x8b) [0x556c364ea4eb]
# [frame 85]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x199c5e) [0x556c36571c5e]
# [frame 86]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyEval_EvalFrameDefault+0x30a) [0x556c3659481a]
# [frame 87]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x193cfb) [0x556c3656bcfb]
# [frame 88]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x199be5) [0x556c36571be5]
# [frame 89]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyEval_EvalFrameDefault+0x30a) [0x556c3659481a]
# [frame 90]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(PyEval_EvalCodeEx+0x966) [0x556c3656d086]
# [frame 91]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x195864) [0x556c3656d864]
# [frame 92]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(PyObject_Call+0x3e) [0x556c364ea10e]
# [frame 93]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyEval_EvalFrameDefault+0x1aaf) [0x556c36595fbf]
# [frame 94]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x193cfb) [0x556c3656bcfb]
# [frame 95]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x199be5) [0x556c36571be5]
# [frame 96]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyEval_EvalFrameDefault+0x30a) [0x556c3659481a]
# [frame 97]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x193cfb) [0x556c3656bcfb]
# [frame 98]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(+0x199be5) [0x556c36571be5]
# [frame 99]: /home/ldh/anaconda3/envs/gg_cnn/bin/python(_PyEval_EvalFrameDefault+0x30a) [0x556c3659481a]
#
# Current pipeline object is no longer valid.

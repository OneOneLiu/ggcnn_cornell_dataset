# %% [markdown]
# # validate程序调试时发现数据集中载入的真实标注有些失真
# validate程序中，可视化对比预测出的抓取框和真实标注抓取框时，预测出的框没问题，但直接读出的真实标注有些失真(如下两图所示)，应该是在cornell数据集对象的处理中出了些问题，这里把两边的流程走一遍，探究一下到底是什么原因。

# %%
import matplotlib.pyplot as plt
import cv2

real_img = cv2.imread('../images/val_img1.png')
dataset_img = cv2.imread('../images/val_img.png')

plt.figure(figsize=(15,10))

plt.subplot(121)
plt.imshow(real_img)
plt.title('rectangles from origin files')
plt.subplot(122)
plt.imshow(dataset_img)
plt.title('rectangles from dataset')
plt.show()

# %% [markdown]
# 可以看到，不仅标注的宽度发生了变化，角度也变了，好像发生了镜像

# %% [markdown]
# 下面追溯一下两个的流程

# %% [markdown]
# ## 1.从原始文件中读出的抓取
# 相关代码如下

# %%
import glob
import os
cornell_path = '../cornell'
graspf = glob.glob(os.path.join(cornell_path,'*','pcd*cpos.txt'))
graspf.sort()

rgbf = [filename.replace('cpos.txt','r.png') for filename in graspf]
depthf = [filename.replace('cpos.txt','d.tiff') for filename in graspf]

def str2num(point):
    '''
    :功能  :将字符串类型存储的抓取框脚点坐标取整并以元组形式返回
    
    :参数  :point,字符串，以字符串形式存储的一个点的坐标
    :返回值 :列表，包含int型抓取点数据的列表[x,y]
    '''
    x,y = point.split()
    x,y = int(round(float(x))),int(round(float(y)))
    
    return (x,y)

def get_rectangles(cornell_grasp_file):
    '''
    :功能  :从抓取文件中提取抓取框的坐标信息
    
    :参数  :cornell_grap_file:字符串，指向某个抓取文件的路径
    :返回值 :列表，包含各个抓取矩形数据的列表
    '''
    grasp_rectangles = []
    with open(cornell_grasp_file,'r') as f:
        while True:
            grasp_rectangle = []
            point0 = f.readline().strip()
            if not point0:
                break
            point1,point2,point3 = f.readline().strip(),f.readline().strip(),f.readline().strip()
            grasp_rectangle = [str2num(point0),
                               str2num(point1),
                               str2num(point2),
                               str2num(point3)]
            grasp_rectangles.append(grasp_rectangle)
    
    return grasp_rectangles
def draw_rectangles(img_path,grasp_path):
    '''
    :功能  :在指定的图片上绘制添加相应的抓取标注框
    
    :参数  :img_path:字符串，指向某个RGB图片的路径
    :参数  :grasp_path:字符串，指向某个抓取文件的路径
    :返回值 :numpy数组，已经添加完抓取框的img数组
    '''
    img_path = img_path
    grasp_path = grasp_path
    
    img = cv2.imread(img_path)
    grs = get_rectangles(grasp_path)
    
    for gr in grs:
        #产生随机颜色
        #color = (random.randint(0,255),random.randint(0,255),random.randint(0,255))
        color1 = (0,0,0)
        color2 = (255,0,0)
        #绘制添加矩形框
        for i in range(3): #因为一个框只有四条线，所以这里是3
            cv2.line(img,gr[i],gr[i+1],color1 if i % 2 == 0 else color2,1)
        cv2.line(img,gr[3],gr[0],color2,1) #补上最后一条封闭的线
    plt.figure(figsize = (10,10))
    plt.imshow(img)
    plt.show()
    
    return img

idx = 1
img = draw_rectangles(rgbf[idx],graspf[idx])

# %% [markdown]
# 这没什么好看的，就是从原始的txt文件中把点坐标读出来了，数值上的变化仅仅是经过了一个str2num的处理，里面做了一个取整的操作，再无其他。

# %% [markdown]
# ## 2.从数据集中读出的抓取
# 相关的代码如下

# %%
from cornell_pro import Cornell
from image_pro import Image
dataset = Cornell('../cornell')

grasps_true = dataset.get_raw_grasps(idx)

# %%
#这是一个Grasps对象
print(type(grasps_true))
# Out:
# <class 'grasp_pro.Grasps'>

# %%
grasps_true.grs

# %%
img = Image.from_file(rgbf[idx])
left = dataset._get_crop_attrs(idx)[1]
top = dataset._get_crop_attrs(idx)[2]

img.crop((left,top),(top+300,left+300))

img1 = img.img.copy()
for gr in grasps_true.grs:
    cv2.rectangle(img1,tuple(gr.points[0]),tuple(gr.points[2]),2)

# %%
plt.figure(figsize=(10,10))
plt.imshow(img1)
plt.show()

# %% [markdown]
# 写到这就真相了，这个抓取矩形能用rectangle函数来画？？？
#
# 之前早就发现的问题好吧，它只能画方方正正竖直的矩形，斜的是画不了的，要用line函数来画好吧。这就说明之前是没有问题的

# %%
#应该这么写
img2 = img.img.copy()

color1 = (0,0,0)
color2 = (255,0,0)
for gr in grasps_true.grs:
    for i in range(3):
        img = cv2.line(img2,tuple(gr.points[i]),tuple(gr.points[i+1]),color1 if i % 2 == 0 else color2,1)
    img = cv2.line(img2,tuple(gr.points[3]),tuple(gr.points[0]),color2,1) #补上最后一条封闭的线

# %%
plt.figure(figsize=(5,5))
plt.imshow(img2)
plt.show()

# %% [markdown]
# 这不就好了吗，所以，原始的程序是没有问题的，只是可视化的函数用错了。

# %% [markdown]
# 可以看一下对比的结果，就是这个矩形绘制函数的问题
# ![comparision](../images/val_img2.png)

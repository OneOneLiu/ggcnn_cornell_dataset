# %% [markdown]
# # 问题描述
# 原先的获取原始抓取矩形函数里面没有添加旋转和缩放功能，当我们实际的训练和验证数据没有进行缩放和旋转时，肯定没有问题，如下图

# %%
from cornell_pro_wrong import Cornell

dataset1 = Cornell('../cornell')

# %%
idx = 0
img = dataset1.get_rgb(idx)
raw_grasp1 = dataset1.get_raw_grasps(idx)

raw_grasp1.show(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# 可以看到，这时的标注是没有问题的，真实标注正确，但如果我们的数据进行了增强，让图片进行了旋转和缩放，还是用原先数据的话，还用原先的抓取真实标注显然不对，如下图。

# %%
idx = 276
img = dataset1.get_rgb(idx,rot = 0.57,zoom = 0.8)
raw_grasp1 = dataset1.get_raw_grasps(idx)

raw_grasp1.show(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# 这一问题对训练没有任何影响，只是验证的时候，精度计算不准确，问题的解决也简单，就是在get_raw_grasp函数里面加上抓取框的旋转和缩放即可，修改后的效果如下图

# %%
from cornell_pro import Cornell

dataset2 = Cornell('../cornell')

# %%
img = dataset2.get_rgb(idx,rot = 3.14,zoom = 0.8)
raw_grasp2 = dataset2.get_raw_grasps(idx,rot = 3.14,zoom = 0.8)

raw_grasp2.show(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# 本来问题到这就应该结束了，也没必要写一篇笔记，但是更改晚之后的文件却不能计算iou了，报下面这个错误：
#
# ValueError: zero-size array to reduction operation maximum which has no identity
#
# 所以来研究一下，思路就是模拟一下这个计算过程，看到底是哪里出了问题。

# %% [markdown]
# 经过资料查阅，传递空数组给某个函数时就会报这个错误，比如下面这种情况

# %%
import numpy as np
a = np.array([])
a.max()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-be1e383e1e0c> in <module>
#       2 import numpy as np
#       3 a = np.array([])
# ----> 4 a.max()
#
# D:\ProgramData\Anaconda3\envs\gg-cnn\lib\site-packages\numpy\core\_methods.py in _amax(a, axis, out, keepdims, initial, where)
#      28 def _amax(a, axis=None, out=None, keepdims=False,
#      29           initial=_NoValue, where=True):
# ---> 30     return umr_maximum(a, axis, None, out, keepdims, initial, where)
#      31
#      32 def _amin(a, axis=None, out=None, keepdims=False,
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %% [markdown]
# 进一步测试，定位到了functions文件里面iou函数的这一句：

# %%
rrc2 = polygon(grasp_true.points[:, 0], grasp_true.points[:, 1])

# %% [markdown]
# 实测有时候这边计算返回的rr2是空的，后面再执行rr2.max()的时候就会报上面的错误,找到位置了，下面就看怎么解决这个问题

# %% [markdown]
# 解决也简单，看了一下ggcnn里面，直接就在这里加了一个故障处理

# %%
try:
    r_max = max(rr1.max(), rr2.max()) + 1
    c_max = max(cc1.max(), cc2.max()) + 1
except:
    return 0
# Out:
#   File "<ipython-input-13-bdc41e332f18>", line 5
#     return 0
#     ^
# SyntaxError: 'return' outside function

# %%
result

# %% [markdown]
# # 可以开始训练了
# - by 刘道会
# - 2020-08 于重庆大学

# %% [markdown]
# 基本流程如下：
# - 导入数据集
# - 导入网络模型
# - 定义主函数
#  - 定义训练参数
#  - 定义优化器
#  - 定义主循环

# %% [markdown]
# ## 0.正式开始前还是简单先测试一下

# %%
import torch
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np

from cornell_pro import Cornell
from ggcnn import GGCNN

# %%
#准备数据集
cornell_data = Cornell('../cornell')
dataset = torch.utils.data.DataLoader(cornell_data,batch_size = 32)

#从数据集中读取一个样本
for x,y in dataset:
    xc = x
    yc = y
    break

# %%
#实例化一个网络
net = GGCNN(4)

#定义一个优化器
optimizer = optim.Adam(net.parameters())

#将输入传递到网络并计算输出
pos,cos,sin,width = net.forward(xc)

# %%
plt.subplot(141)
plt.title('pos_out')
plt.imshow(pos[0][0].data.numpy())
plt.subplot(142)
plt.title('cos_out')
plt.imshow(cos[0][0].data.numpy())
plt.subplot(143)
plt.title('sin_out')
plt.imshow(sin[0][0].data.numpy())
plt.subplot(144)
plt.title('width_out')
plt.imshow(width[0][0].data.numpy())
plt.show()

# %%
#计算损失
losses = net.compute_loss(xc,yc)
loss = losses['loss']

print(loss)
# Out:
# tensor(1.0342, grad_fn=<AddBackward0>)

# %%
#反向传播优化
optimizer.zero_grad()
loss.backward()

optimizer.step()

# %%
losses = net.compute_loss(xc,yc)
loss = losses['loss']

print(loss)
# Out:
# tensor(1.0079, grad_fn=<AddBackward0>)

# %% [markdown]
# 可以看到经过一次优化之后，loss减小了，不过一次说明不了什么，下面就在这一个样本上优化一百次，看看loss如果变得很小的话，就说明目前的工作没有跑偏，可以继续

# %%
'''
device = torch.device("cuda:0")

net = net.to(device)

x = xc.to(device)
y = [yy.to(device) for yy in yc]

'''
#这些是指定GPU为训练设备的代码，但不知道为什么在jupyter notebook里面会报错，但是在spyder里面是没有问题的，训练速度那叫一个快，
#因为jupyter这边主要是为了调试，也不会真的训练，所以暂时就这样吧，不管了，用cpu就用cpu吧,不过gpu的速度比cpu快了感觉不下30倍，
#因为jupyter这开始训练之后，我spyder那边调了挺久，后面又迭代了1000次，结果回过头来jupyter这还是没迭代完100次
# Out:
# '\ndevice = torch.device("cuda:0")\n\nnet = net.to(device)\n\nx = xc.to(device)\ny = [yy.to(device) for yy in yc]\n\n'

# %%
for i in range(10):
    losses = net.compute_loss(xc,yc)
    loss = losses['loss']
    print(i)
    print(loss)
    
    #反向传播优化
    optimizer.zero_grad()
    loss.backward()
    
    optimizer.step()
# Out:
# 0
# tensor(1.0079, grad_fn=<AddBackward0>)
# 1
# tensor(0.9818, grad_fn=<AddBackward0>)
# 2
# tensor(0.9540, grad_fn=<AddBackward0>)
# 3
# tensor(0.9233, grad_fn=<AddBackward0>)
# 4
# tensor(0.8871, grad_fn=<AddBackward0>)
# 5
# tensor(0.8415, grad_fn=<AddBackward0>)
# 6
# tensor(0.7801, grad_fn=<AddBackward0>)
# 7
# tensor(0.6944, grad_fn=<AddBackward0>)
# 8
# tensor(0.5760, grad_fn=<AddBackward0>)
# 9
# tensor(0.4224, grad_fn=<AddBackward0>)

# %% [markdown]
# 可以看到loss一直在降低，说明训练有效，再可视化看一下它训练完后的预测结果，所以ojbk，开整

# %%
pos,cos,sin,width = net.forward(xc)

num = 20

plt.subplot(141)
plt.title('pos_out')
plt.imshow(pos[num][0].data.numpy(),cmap=plt.cm.gray)
plt.subplot(142)
plt.title('cos_out')
plt.imshow(cos[num][0].data.numpy(),cmap=plt.cm.gray)
plt.subplot(143)
plt.title('sin_out')
plt.imshow(sin[num][0].data.numpy(),cmap=plt.cm.gray)
plt.subplot(144)
plt.title('width_out')
plt.imshow(width[num][0].data.numpy(),cmap=plt.cm.gray)
plt.show()

# %% [markdown]
# 可以看到，是比较符合预期的，所以，前面的工作已经做完了，后面可以集成了。
#
# 后面在这一个batch上迭代训练了很多次，并将过程可视化了出来，详见程序train_main1.py

# %% [markdown]
# ## 1.导入数据集并进行必要的参数设置

# %%
cornell_data = Cornell('../cornell')
dataset = torch.utils.data.DataLoader(cornell_data,batch_size = 32,shuffle = True)

batch_size = 32
batches_per_epoch = 1000
epochs = 30
lr = 0.001

# %% [markdown]
# ## 2.导入网络模型并进行必要的参数设置

# %%
#实例化一个网络
net = GGCNN(4)

# %% [markdown]
# ## 3.定义各个子函数

# %% [markdown]
# ### 3.1定义训练函数

# %%
def train(epoch,net,device,train_data,optimizer,batches_per_epoch):
    """
    :功能: 执行一个训练epoch
    :参数: epoch             : 当前所在的epoch数
    :参数: net               : 要使用的网络模型
    :参数: device            : 训练使用的设备
    :参数: train_data        : 训练所用数据集
    :参数: optimizer         : 优化器
    :参数: batches_per_epoch : 每个epoch训练中所用的数据批数

    :返回: 本epoch的平均损失
    """
    #结果字典，最后返回用
    results = {
        'loss': 0,
        'losses': {
        }
    }
    
    #训练模式，所有的层和参数都会考虑进来，eval模式下比如dropout这种层会不使能
    net.train()
    
    batch_idx = 0
    
    #开始样本训练迭代
    while batch_idx < batches_per_epoch:
        for x, y in train_data:
            batch_idx += 1
            if batch_idx >= batches_per_epoch:
                break
            
            #将数据传到GPU，目前jupyter下无法使用
            # xc = x.to(device)
            # yc = [yy.to(device) for yy in y]
            
            lossdict = net.compute_loss(x,y)
            
            #获取当前损失
            loss = lossdict['loss']
            
            #打印一下训练过程
            if batch_idx % 2 == 0:
                print('Epoch: {}, Batch: {}, Loss: {:0.4f}'.format(epoch, batch_idx, loss.item()))
            
            #记录总共的损失
            results['loss'] += loss.item()
            #单独记录各项损失，pos,cos,sin,width
            for ln, l in lossdict['losses'].items():
                if ln not in results['losses']:
                    results['losses'][ln] = 0
                results['losses'][ln] += l.item()
            
            #反向传播优化模型
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        
        #计算总共的平均损失
        results['loss'] /= batch_idx
        
        #计算各项的平均损失
        for l in results['losses']:
            results['losses'][l] /= batch_idx
        return results

# %%
def run():
    #获取设备
    device = torch.device("cuda:0")
    #net = net.to(device)
    
    #设置优化器
    optimizer = optim.Adam(net.parameters())
    
    #开始主循环
    for epoch in range(epochs):
        train_results = train(epoch, net, device, dataset, optimizer, batches_per_epoch)

# %%
run()
# Out:
# Epoch: 0, Batch: 2, Loss: 1.1090
# Epoch: 0, Batch: 4, Loss: 1.0414
# Epoch: 0, Batch: 6, Loss: 0.9597
# Epoch: 0, Batch: 8, Loss: 0.8057
# Epoch: 0, Batch: 10, Loss: 0.5772
# Epoch: 0, Batch: 12, Loss: 0.2939
# Epoch: 0, Batch: 14, Loss: 0.3768
# Epoch: 0, Batch: 16, Loss: 0.2225
# Epoch: 0, Batch: 18, Loss: 0.1700
# Epoch: 0, Batch: 20, Loss: 0.1907
# Epoch: 0, Batch: 22, Loss: 0.1699
# Epoch: 0, Batch: 24, Loss: 0.1624
# Epoch: 0, Batch: 26, Loss: 0.1324
# Epoch: 0, Batch: 28, Loss: 0.1238
# Epoch: 1, Batch: 2, Loss: 0.1169
# Epoch: 1, Batch: 4, Loss: 0.0911
# Epoch: 1, Batch: 6, Loss: 0.0860
# Epoch: 1, Batch: 8, Loss: 0.0918
# Epoch: 1, Batch: 10, Loss: 0.0880
# Epoch: 1, Batch: 12, Loss: 0.0720
# Epoch: 1, Batch: 14, Loss: 0.0834
# Epoch: 1, Batch: 16, Loss: 0.0784
# Epoch: 1, Batch: 18, Loss: 0.0759
# Epoch: 1, Batch: 20, Loss: 0.0795
# Epoch: 1, Batch: 22, Loss: 0.0686
# Epoch: 1, Batch: 24, Loss: 0.1040
# Epoch: 1, Batch: 26, Loss: 0.0701
# Epoch: 1, Batch: 28, Loss: 0.0721
# Epoch: 2, Batch: 2, Loss: 0.0745
# Epoch: 2, Batch: 4, Loss: 0.0931
# Epoch: 2, Batch: 6, Loss: 0.0687
# Epoch: 2, Batch: 8, Loss: 0.0628
# Epoch: 2, Batch: 10, Loss: 0.0788
# Epoch: 2, Batch: 12, Loss: 0.0758
# Epoch: 2, Batch: 14, Loss: 0.0768
# Epoch: 2, Batch: 16, Loss: 0.0606
# Epoch: 2, Batch: 18, Loss: 0.0761
# Epoch: 2, Batch: 20, Loss: 0.0667
# Epoch: 2, Batch: 22, Loss: 0.0692
# Epoch: 2, Batch: 24, Loss: 0.0989
# Epoch: 2, Batch: 26, Loss: 0.0872
# Epoch: 2, Batch: 28, Loss: 0.0692
# Epoch: 3, Batch: 2, Loss: 0.0668
# Epoch: 3, Batch: 4, Loss: 0.0747
# Epoch: 3, Batch: 6, Loss: 0.0798
# Epoch: 3, Batch: 8, Loss: 0.0696
# Epoch: 3, Batch: 10, Loss: 0.0635
# Epoch: 3, Batch: 12, Loss: 0.0758
# Epoch: 3, Batch: 14, Loss: 0.0704
# Epoch: 3, Batch: 16, Loss: 0.0770
# Epoch: 3, Batch: 18, Loss: 0.0708
# Epoch: 3, Batch: 20, Loss: 0.0671
# Epoch: 3, Batch: 22, Loss: 0.0765
# Epoch: 3, Batch: 24, Loss: 0.0704
# Epoch: 3, Batch: 26, Loss: 0.0755
# Epoch: 3, Batch: 28, Loss: 0.0587
# Epoch: 4, Batch: 2, Loss: 0.0521
# Epoch: 4, Batch: 4, Loss: 0.0774
# Epoch: 4, Batch: 6, Loss: 0.0688
# Epoch: 4, Batch: 8, Loss: 0.0693
# Epoch: 4, Batch: 10, Loss: 0.0820
# Epoch: 4, Batch: 12, Loss: 0.0719
# Epoch: 4, Batch: 14, Loss: 0.0745
# Epoch: 4, Batch: 16, Loss: 0.0661
# Epoch: 4, Batch: 18, Loss: 0.0709
# Epoch: 4, Batch: 20, Loss: 0.0615
# Epoch: 4, Batch: 22, Loss: 0.0727
# Epoch: 4, Batch: 24, Loss: 0.0663
# Epoch: 4, Batch: 26, Loss: 0.0717
# Epoch: 4, Batch: 28, Loss: 0.0835
# Epoch: 5, Batch: 2, Loss: 0.0631
# Epoch: 5, Batch: 4, Loss: 0.0574
# Epoch: 5, Batch: 6, Loss: 0.0665
# Epoch: 5, Batch: 8, Loss: 0.0767
# Epoch: 5, Batch: 10, Loss: 0.0542
# Epoch: 5, Batch: 12, Loss: 0.0676
# Epoch: 5, Batch: 14, Loss: 0.0599
# Epoch: 5, Batch: 16, Loss: 0.0697
# Epoch: 5, Batch: 18, Loss: 0.0514
# Epoch: 5, Batch: 20, Loss: 0.0646
# Epoch: 5, Batch: 22, Loss: 0.0763
# Epoch: 5, Batch: 24, Loss: 0.0640
# Epoch: 5, Batch: 26, Loss: 0.0608
# Epoch: 5, Batch: 28, Loss: 0.0804
# Epoch: 6, Batch: 2, Loss: 0.0814
# Epoch: 6, Batch: 4, Loss: 0.0637
# Epoch: 6, Batch: 6, Loss: 0.0554
# Epoch: 6, Batch: 8, Loss: 0.0567
# Epoch: 6, Batch: 10, Loss: 0.0608
# Epoch: 6, Batch: 12, Loss: 0.0660
# Epoch: 6, Batch: 14, Loss: 0.0573
# Epoch: 6, Batch: 16, Loss: 0.0716
# Epoch: 6, Batch: 18, Loss: 0.0643
# Epoch: 6, Batch: 20, Loss: 0.0636
# Epoch: 6, Batch: 22, Loss: 0.0766
# Epoch: 6, Batch: 24, Loss: 0.0733
# Epoch: 6, Batch: 26, Loss: 0.0618
# Epoch: 6, Batch: 28, Loss: 0.0558
# Epoch: 7, Batch: 2, Loss: 0.0728
# Epoch: 7, Batch: 4, Loss: 0.0651
# Epoch: 7, Batch: 6, Loss: 0.0602
# Epoch: 7, Batch: 8, Loss: 0.0606
# Epoch: 7, Batch: 10, Loss: 0.0563
# Epoch: 7, Batch: 12, Loss: 0.0670
# Epoch: 7, Batch: 14, Loss: 0.0560
# Epoch: 7, Batch: 16, Loss: 0.0669
# Epoch: 7, Batch: 18, Loss: 0.0549
# Epoch: 7, Batch: 20, Loss: 0.0804
# Epoch: 7, Batch: 22, Loss: 0.0569
# Epoch: 7, Batch: 24, Loss: 0.0665
# Epoch: 7, Batch: 26, Loss: 0.0633
# Epoch: 7, Batch: 28, Loss: 0.0724
# Epoch: 8, Batch: 2, Loss: 0.0604
# Epoch: 8, Batch: 4, Loss: 0.0512
# Epoch: 8, Batch: 6, Loss: 0.0564
# Epoch: 8, Batch: 8, Loss: 0.0515
# Epoch: 8, Batch: 10, Loss: 0.0712
# Epoch: 8, Batch: 12, Loss: 0.0620
# Epoch: 8, Batch: 14, Loss: 0.0704
# Epoch: 8, Batch: 16, Loss: 0.0700
# Epoch: 8, Batch: 18, Loss: 0.0552
# Epoch: 8, Batch: 20, Loss: 0.0625
# Epoch: 8, Batch: 22, Loss: 0.0704
# Epoch: 8, Batch: 24, Loss: 0.0507
# Epoch: 8, Batch: 26, Loss: 0.0623
# Epoch: 8, Batch: 28, Loss: 0.0566
# Epoch: 9, Batch: 2, Loss: 0.0630
# Epoch: 9, Batch: 4, Loss: 0.0442
# Epoch: 9, Batch: 6, Loss: 0.0644
# Epoch: 9, Batch: 8, Loss: 0.0610
# Epoch: 9, Batch: 10, Loss: 0.0563
# Epoch: 9, Batch: 12, Loss: 0.0600
# Epoch: 9, Batch: 14, Loss: 0.0574
# Epoch: 9, Batch: 16, Loss: 0.0605
# Epoch: 9, Batch: 18, Loss: 0.0601
# Epoch: 9, Batch: 20, Loss: 0.0536
# Epoch: 9, Batch: 22, Loss: 0.0608
# Epoch: 9, Batch: 24, Loss: 0.0641
# Epoch: 9, Batch: 26, Loss: 0.0697
# Epoch: 9, Batch: 28, Loss: 0.0622
# Epoch: 10, Batch: 2, Loss: 0.0654
# Epoch: 10, Batch: 4, Loss: 0.0486
# Epoch: 10, Batch: 6, Loss: 0.0645
# Epoch: 10, Batch: 8, Loss: 0.0590
# Epoch: 10, Batch: 10, Loss: 0.0608
# Epoch: 10, Batch: 12, Loss: 0.0516
# Epoch: 10, Batch: 14, Loss: 0.0695
# Epoch: 10, Batch: 16, Loss: 0.0572
# Epoch: 10, Batch: 18, Loss: 0.0496
# Epoch: 10, Batch: 20, Loss: 0.0639
# Epoch: 10, Batch: 22, Loss: 0.0532
# Epoch: 10, Batch: 24, Loss: 0.0583
# Epoch: 10, Batch: 26, Loss: 0.0567
# Epoch: 10, Batch: 28, Loss: 0.0681
# Epoch: 11, Batch: 2, Loss: 0.0415
# Epoch: 11, Batch: 4, Loss: 0.0604
# Epoch: 11, Batch: 6, Loss: 0.0484
# Epoch: 11, Batch: 8, Loss: 0.0546
# Epoch: 11, Batch: 10, Loss: 0.0495
# Epoch: 11, Batch: 12, Loss: 0.0533
# Epoch: 11, Batch: 14, Loss: 0.0598
# Epoch: 11, Batch: 16, Loss: 0.0513
# Epoch: 11, Batch: 18, Loss: 0.0494
# Epoch: 11, Batch: 20, Loss: 0.0652
# Epoch: 11, Batch: 22, Loss: 0.0446
# Epoch: 11, Batch: 24, Loss: 0.0560
# Epoch: 11, Batch: 26, Loss: 0.0546
# Epoch: 11, Batch: 28, Loss: 0.0708
# Epoch: 12, Batch: 2, Loss: 0.0578
# Epoch: 12, Batch: 4, Loss: 0.0514
# Epoch: 12, Batch: 6, Loss: 0.0530
# Epoch: 12, Batch: 8, Loss: 0.0429
# Epoch: 12, Batch: 10, Loss: 0.0486
# Epoch: 12, Batch: 12, Loss: 0.0520
# Epoch: 12, Batch: 14, Loss: 0.0526
# Epoch: 12, Batch: 16, Loss: 0.0555
# Epoch: 12, Batch: 18, Loss: 0.0646
# Epoch: 12, Batch: 20, Loss: 0.0447
# Epoch: 12, Batch: 22, Loss: 0.0472
# Epoch: 12, Batch: 24, Loss: 0.0610
# Epoch: 12, Batch: 26, Loss: 0.0527
# Epoch: 12, Batch: 28, Loss: 0.0502
# Epoch: 13, Batch: 2, Loss: 0.0602
# Epoch: 13, Batch: 4, Loss: 0.0557
# Epoch: 13, Batch: 6, Loss: 0.0457
# Epoch: 13, Batch: 8, Loss: 0.0567
# Epoch: 13, Batch: 10, Loss: 0.0471
# Epoch: 13, Batch: 12, Loss: 0.0528
# Epoch: 13, Batch: 14, Loss: 0.0434
# Epoch: 13, Batch: 16, Loss: 0.0565
# Epoch: 13, Batch: 18, Loss: 0.0469
# Epoch: 13, Batch: 20, Loss: 0.0396
# Epoch: 13, Batch: 22, Loss: 0.0480
# Epoch: 13, Batch: 24, Loss: 0.0545
# Epoch: 13, Batch: 26, Loss: 0.0523
# Epoch: 13, Batch: 28, Loss: 0.0459
# Epoch: 14, Batch: 2, Loss: 0.0525
# Epoch: 14, Batch: 4, Loss: 0.0521
# Epoch: 14, Batch: 6, Loss: 0.0353
# Epoch: 14, Batch: 8, Loss: 0.0430
# Epoch: 14, Batch: 10, Loss: 0.0449
# Epoch: 14, Batch: 12, Loss: 0.0509
# Epoch: 14, Batch: 14, Loss: 0.0571
# Epoch: 14, Batch: 16, Loss: 0.0487
# Epoch: 14, Batch: 18, Loss: 0.0493
# Epoch: 14, Batch: 20, Loss: 0.0554
# Epoch: 14, Batch: 22, Loss: 0.0525
# Epoch: 14, Batch: 24, Loss: 0.0495
# Epoch: 14, Batch: 26, Loss: 0.0533
# Epoch: 14, Batch: 28, Loss: 0.0527
# Epoch: 15, Batch: 2, Loss: 0.0553
# Epoch: 15, Batch: 4, Loss: 0.0465
# Epoch: 15, Batch: 6, Loss: 0.0445
# Epoch: 15, Batch: 8, Loss: 0.0508
# Epoch: 15, Batch: 10, Loss: 0.0488
# Epoch: 15, Batch: 12, Loss: 0.0620
# Epoch: 15, Batch: 14, Loss: 0.0528
# Epoch: 15, Batch: 16, Loss: 0.0399
# Epoch: 15, Batch: 18, Loss: 0.0479
# Epoch: 15, Batch: 20, Loss: 0.0447
# Epoch: 15, Batch: 22, Loss: 0.0442
# Epoch: 15, Batch: 24, Loss: 0.0418
# Epoch: 15, Batch: 26, Loss: 0.0470
# Epoch: 15, Batch: 28, Loss: 0.0580
# Epoch: 16, Batch: 2, Loss: 0.0478
# Epoch: 16, Batch: 4, Loss: 0.0503
# Epoch: 16, Batch: 6, Loss: 0.0518
# Epoch: 16, Batch: 8, Loss: 0.0598
# Epoch: 16, Batch: 10, Loss: 0.0476
# Epoch: 16, Batch: 12, Loss: 0.0597
# Epoch: 16, Batch: 14, Loss: 0.0526
# Epoch: 16, Batch: 16, Loss: 0.0465
# Epoch: 16, Batch: 18, Loss: 0.0486
# Epoch: 16, Batch: 20, Loss: 0.0646
# Epoch: 16, Batch: 22, Loss: 0.0366
# Epoch: 16, Batch: 24, Loss: 0.0505
# Epoch: 16, Batch: 26, Loss: 0.0479
# Epoch: 16, Batch: 28, Loss: 0.0367
# Epoch: 17, Batch: 2, Loss: 0.0436
# Epoch: 17, Batch: 4, Loss: 0.0397
# Epoch: 17, Batch: 6, Loss: 0.0443
# Epoch: 17, Batch: 8, Loss: 0.0440
# Epoch: 17, Batch: 10, Loss: 0.0577
# Epoch: 17, Batch: 12, Loss: 0.0491
# Epoch: 17, Batch: 14, Loss: 0.0595
# Epoch: 17, Batch: 16, Loss: 0.0559
# Epoch: 17, Batch: 18, Loss: 0.0614
# Epoch: 17, Batch: 20, Loss: 0.0434
# Epoch: 17, Batch: 22, Loss: 0.0503
# Epoch: 17, Batch: 24, Loss: 0.0507
# Epoch: 17, Batch: 26, Loss: 0.0596
# Epoch: 17, Batch: 28, Loss: 0.0572
# Epoch: 18, Batch: 2, Loss: 0.0496
# Epoch: 18, Batch: 4, Loss: 0.0459
# Epoch: 18, Batch: 6, Loss: 0.0614
# Epoch: 18, Batch: 8, Loss: 0.0458
# Epoch: 18, Batch: 10, Loss: 0.0414
# Epoch: 18, Batch: 12, Loss: 0.0444
# Epoch: 18, Batch: 14, Loss: 0.0468
# Epoch: 18, Batch: 16, Loss: 0.0575
# Epoch: 18, Batch: 18, Loss: 0.0515
# Epoch: 18, Batch: 20, Loss: 0.0368
# Epoch: 18, Batch: 22, Loss: 0.0419
# Epoch: 18, Batch: 24, Loss: 0.0407
# Epoch: 18, Batch: 26, Loss: 0.0502
# Epoch: 18, Batch: 28, Loss: 0.0510
# Epoch: 19, Batch: 2, Loss: 0.0451
# Epoch: 19, Batch: 4, Loss: 0.0564
# Epoch: 19, Batch: 6, Loss: 0.0448
# Epoch: 19, Batch: 8, Loss: 0.0499
# Epoch: 19, Batch: 10, Loss: 0.0531
# Epoch: 19, Batch: 12, Loss: 0.0458
# Epoch: 19, Batch: 14, Loss: 0.0620
# Epoch: 19, Batch: 16, Loss: 0.0454
# Epoch: 19, Batch: 18, Loss: 0.0558
# Epoch: 19, Batch: 20, Loss: 0.0422
# Epoch: 19, Batch: 22, Loss: 0.0492
# Epoch: 19, Batch: 24, Loss: 0.0407
# Epoch: 19, Batch: 26, Loss: 0.0451
# Epoch: 19, Batch: 28, Loss: 0.0399
# Epoch: 20, Batch: 2, Loss: 0.0448
# Epoch: 20, Batch: 4, Loss: 0.0490
# Epoch: 20, Batch: 6, Loss: 0.0506
# Epoch: 20, Batch: 8, Loss: 0.0439
# Epoch: 20, Batch: 10, Loss: 0.0543
# Epoch: 20, Batch: 12, Loss: 0.0417
# Epoch: 20, Batch: 14, Loss: 0.0461
# Epoch: 20, Batch: 16, Loss: 0.0553
# Epoch: 20, Batch: 18, Loss: 0.0447
# Epoch: 20, Batch: 20, Loss: 0.0411
# Epoch: 20, Batch: 22, Loss: 0.0585
# Epoch: 20, Batch: 24, Loss: 0.0448
# Epoch: 20, Batch: 26, Loss: 0.0446
# Epoch: 20, Batch: 28, Loss: 0.0507
# Epoch: 21, Batch: 2, Loss: 0.0572
# Epoch: 21, Batch: 4, Loss: 0.0454
# Epoch: 21, Batch: 6, Loss: 0.0474
# Epoch: 21, Batch: 8, Loss: 0.0508
# Epoch: 21, Batch: 10, Loss: 0.0458
# Epoch: 21, Batch: 12, Loss: 0.0605
# Epoch: 21, Batch: 14, Loss: 0.0413
# Epoch: 21, Batch: 16, Loss: 0.0488
# Epoch: 21, Batch: 18, Loss: 0.0405
# Epoch: 21, Batch: 20, Loss: 0.0324
# Epoch: 21, Batch: 22, Loss: 0.0539
# Epoch: 21, Batch: 24, Loss: 0.0531
# Epoch: 21, Batch: 26, Loss: 0.0516
# Epoch: 21, Batch: 28, Loss: 0.0457
# Epoch: 22, Batch: 2, Loss: 0.0369
# Epoch: 22, Batch: 4, Loss: 0.0493
# Epoch: 22, Batch: 6, Loss: 0.0488
# Epoch: 22, Batch: 8, Loss: 0.0457
# Epoch: 22, Batch: 10, Loss: 0.0384
# Epoch: 22, Batch: 12, Loss: 0.0633
# Epoch: 22, Batch: 14, Loss: 0.0466
# Epoch: 22, Batch: 16, Loss: 0.0512
# Epoch: 22, Batch: 18, Loss: 0.0502
# Epoch: 22, Batch: 20, Loss: 0.0392
# Epoch: 22, Batch: 22, Loss: 0.0642
# Epoch: 22, Batch: 24, Loss: 0.0586
# Epoch: 22, Batch: 26, Loss: 0.0436
# Epoch: 22, Batch: 28, Loss: 0.0554
# Epoch: 23, Batch: 2, Loss: 0.0427
# Epoch: 23, Batch: 4, Loss: 0.0505
# Epoch: 23, Batch: 6, Loss: 0.0343
# Epoch: 23, Batch: 8, Loss: 0.0504
# Epoch: 23, Batch: 10, Loss: 0.0445
# Epoch: 23, Batch: 12, Loss: 0.0357
# Epoch: 23, Batch: 14, Loss: 0.0444
# Epoch: 23, Batch: 16, Loss: 0.0520
# Epoch: 23, Batch: 18, Loss: 0.0492
# Epoch: 23, Batch: 20, Loss: 0.0519
# Epoch: 23, Batch: 22, Loss: 0.0437
# Epoch: 23, Batch: 24, Loss: 0.0518
# Epoch: 23, Batch: 26, Loss: 0.0467
# Epoch: 23, Batch: 28, Loss: 0.0665
# Epoch: 24, Batch: 2, Loss: 0.0470
# Epoch: 24, Batch: 4, Loss: 0.0532
# Epoch: 24, Batch: 6, Loss: 0.0365
# Epoch: 24, Batch: 8, Loss: 0.0384
# Epoch: 24, Batch: 10, Loss: 0.0549
# Epoch: 24, Batch: 12, Loss: 0.0470
# Epoch: 24, Batch: 14, Loss: 0.0432
# Epoch: 24, Batch: 16, Loss: 0.0350
# Epoch: 24, Batch: 18, Loss: 0.0527
# Epoch: 24, Batch: 20, Loss: 0.0413
# Epoch: 24, Batch: 22, Loss: 0.0468
# Epoch: 24, Batch: 24, Loss: 0.0404
# Epoch: 24, Batch: 26, Loss: 0.0513
# Epoch: 24, Batch: 28, Loss: 0.0444
# Epoch: 25, Batch: 2, Loss: 0.0501
# Epoch: 25, Batch: 4, Loss: 0.0525
# Epoch: 25, Batch: 6, Loss: 0.0384
# Epoch: 25, Batch: 8, Loss: 0.0514
# Epoch: 25, Batch: 10, Loss: 0.0533
# Epoch: 25, Batch: 12, Loss: 0.0366
# Epoch: 25, Batch: 14, Loss: 0.0461
# Epoch: 25, Batch: 16, Loss: 0.0558
# Epoch: 25, Batch: 18, Loss: 0.0371
# Epoch: 25, Batch: 20, Loss: 0.0487
# Epoch: 25, Batch: 22, Loss: 0.0449
# Epoch: 25, Batch: 24, Loss: 0.0499
# Epoch: 25, Batch: 26, Loss: 0.0501
# Epoch: 25, Batch: 28, Loss: 0.0410
# Epoch: 26, Batch: 2, Loss: 0.0532
# Epoch: 26, Batch: 4, Loss: 0.0459
# Epoch: 26, Batch: 6, Loss: 0.0488
# Epoch: 26, Batch: 8, Loss: 0.0509
# Epoch: 26, Batch: 10, Loss: 0.0385
# Epoch: 26, Batch: 12, Loss: 0.0520
# Epoch: 26, Batch: 14, Loss: 0.0382
# Epoch: 26, Batch: 16, Loss: 0.0399
# Epoch: 26, Batch: 18, Loss: 0.0409
# Epoch: 26, Batch: 20, Loss: 0.0474
# Epoch: 26, Batch: 22, Loss: 0.0457
# Epoch: 26, Batch: 24, Loss: 0.0384
# Epoch: 26, Batch: 26, Loss: 0.0508
# Epoch: 26, Batch: 28, Loss: 0.0641
# Epoch: 27, Batch: 2, Loss: 0.0512
# Epoch: 27, Batch: 4, Loss: 0.0499
# Epoch: 27, Batch: 6, Loss: 0.0373
# Epoch: 27, Batch: 8, Loss: 0.0508
# Epoch: 27, Batch: 10, Loss: 0.0523
# Epoch: 27, Batch: 12, Loss: 0.0485
# Epoch: 27, Batch: 14, Loss: 0.0475
# Epoch: 27, Batch: 16, Loss: 0.0441
# Epoch: 27, Batch: 18, Loss: 0.0437
# Epoch: 27, Batch: 20, Loss: 0.0541
# Epoch: 27, Batch: 22, Loss: 0.0588
# Epoch: 27, Batch: 24, Loss: 0.0354
# Epoch: 27, Batch: 26, Loss: 0.0523
# Epoch: 27, Batch: 28, Loss: 0.0442
# Epoch: 28, Batch: 2, Loss: 0.0468
# Epoch: 28, Batch: 4, Loss: 0.0487
# Epoch: 28, Batch: 6, Loss: 0.0425
# Epoch: 28, Batch: 8, Loss: 0.0351
# Epoch: 28, Batch: 10, Loss: 0.0422
# Epoch: 28, Batch: 12, Loss: 0.0417
# Epoch: 28, Batch: 14, Loss: 0.0459
# Epoch: 28, Batch: 16, Loss: 0.0469
# Epoch: 28, Batch: 18, Loss: 0.0556
# Epoch: 28, Batch: 20, Loss: 0.0489
# Epoch: 28, Batch: 22, Loss: 0.0390
# Epoch: 28, Batch: 24, Loss: 0.0557
# Epoch: 28, Batch: 26, Loss: 0.0402
# Epoch: 28, Batch: 28, Loss: 0.0527
# Epoch: 29, Batch: 2, Loss: 0.0497
# Epoch: 29, Batch: 4, Loss: 0.0432
# Epoch: 29, Batch: 6, Loss: 0.0478
# Epoch: 29, Batch: 8, Loss: 0.0438
# Epoch: 29, Batch: 10, Loss: 0.0399
# Epoch: 29, Batch: 12, Loss: 0.0452
# Epoch: 29, Batch: 14, Loss: 0.0462
# Epoch: 29, Batch: 16, Loss: 0.0572
# Epoch: 29, Batch: 18, Loss: 0.0550
# Epoch: 29, Batch: 20, Loss: 0.0493
# Epoch: 29, Batch: 22, Loss: 0.0484
# Epoch: 29, Batch: 24, Loss: 0.0651
# Epoch: 29, Batch: 26, Loss: 0.0398
# Epoch: 29, Batch: 28, Loss: 0.0454

# %% [markdown]
# 这边训练的时候，一开始没问题，后面报了这个错误，说是维度不匹配，有的图是[4,299,300]，这就说明是裁剪那块出了问题，上网查了一下也没什么结果，不过好在这是复现，ggcnn那边没报错，就说明它肯定是解决了这个问题的，cornell_data里面的get_depth和git_rgb有个resize函数，估计是解决这个问题的，我拿来试试

# %% [markdown]
# 果然解决了，不过又报了一个新的错误：'Cannot warp empty image with dimensions', (0, 300))

# %% [markdown]
# 调试过程如下：因为他说shape是（0,300），那么在image_resize之前加上一句print(self.img.shape)后面打印了发现确实有个数据是（0,300），这就是异常数据了，然后在cornell里面的\_\_getitem\_\_后面加一句print(idx)，看一下到底是哪一个，然后发现是360,计算一下，那就是大概第四个文件夹第60张图片的样子。

# %%
(300, 300, 3)
28
(300, 300, 3)
283
(300, 300, 3)
248
(300, 300, 3)
604
(300, 300, 3)
559
(300, 300, 3)
360
(0, 300)
# Out:
# (0, 300)

# %% [markdown]
# 打开看一下是这样的：
# ![pcd0460r.png](../images/pcd0460r.png)

# %% [markdown]
# 这也太偏了吧，按照之前的策略对其进行裁剪的话肯定会出问题的，这就是之前在net_data_stream里面，被我缺省掉的裁剪边界代码的取值判定的作用，当时觉得对象大都放置在中心，还是太天真了，现在乖乖地加回来吧。

# %% [markdown]
# 先看看对这个图片直接裁剪的话会怎么样

# %%
#先把文件都读进来
import os
import glob
import cv2
import matplotlib.pyplot as plt

from image_pro import Image
from image_pro import DepthImage
from grasp_pro import Grasps



cornell_path = '../cornell'
graspf = glob.glob(os.path.join(cornell_path,'*','pcd*cpos.txt'))
graspf.sort()

rgbf = [filename.replace('cpos.txt','r.png') for filename in graspf]
depthf = [filename.replace('cpos.txt','d.tiff') for filename in graspf]

rgb_img = Image.from_file(rgbf[360])
depth_img = DepthImage.from_file(depthf[360])

grasps = Grasps.load_from_cornell_files(graspf[360])

output_size = (300,300)

center = grasps.center

#注意原点在左上角
top_left = (int(center[0]-output_size[0]//2),int(center[1]-output_size[1]//2))
bottom_right = (int(center[0]+output_size[0]//2),int(center[1]+output_size[1]//2))

cv2.rectangle(rgb_img.img,top_left,bottom_right,(0,0,1))
cv2.rectangle(depth_img.img,top_left,bottom_right,(0,0,1))

plt.subplot(121)
plt.imshow(rgb_img.img)
plt.subplot(122)
plt.imshow(depth_img.img)
plt.show()

# %% [markdown]
# 可以看到，边框溢出边界了，这时候如果对其进行裁剪的话看一下会得到什么？

# %%
rgb_img.crop(top_left,bottom_right)
rgb_img.img.shape
# Out:
# (0, 300, 3)

# %% [markdown]
# 得到了一个行数为0的矩阵，说明出现了错误，看一下top_left和bottom_right的值

# %%
print(top_left,bottom_right)
# Out:
# (155, -7) (455, 293)

# %% [markdown]
# 可以看到里面出现了负数，后面裁剪切片的时候是这样的：

# %%
self.img = self.img[top_left[1]:bottom_right[1], top_left[0]:bottom_right[0]]

# %% [markdown]
# 代入数据的是这样的：

# %%
self.img = self.img[-7:293, 155:455]

# %% [markdown]
# numpy数组切片索引出现负数，这个工作机制怎么说？测试一下

# %% [markdown]
# 这时候行数上的返回为空，至于为什么为空已经在support_files里面测试过了，参见functions 第6个问题

# %% [markdown]
# 解决方式是在切割参数（top_left,bottom_right）生成时加上判别参数，如果left和top点小于0,则指定为0。

# %%
left = max(0, min(center[0] - self.output_size // 2, 640 - self.output_size))
top = max(0, min(center[1] - self.output_size // 2, 480 - self.output_size))

# %% [markdown]
# max函数确保角点不会溢出左上边界，里面的min函数控制不会溢出右下边界

# %% [markdown]
# 此外，我这里还有过一个错误想法，就是，本来我这张图是以grs.center也就是多抓取框中心为中心所裁出来的一个（output_size,output_size）大小的一张图，如果现在我的边界要延伸到-7处开始裁剪才能保证图的大小，你现在硬生生地给我限制在了0处，那么我的图不就不足原先那么大了吗，少了7行？
#
# 这种想法是错误的，因为这里确定的仅仅是左上角点而已，真正去裁的时候，图片整体的另外角点是由左上角点结合output_size实际加来的，最后大小肯定还是（output_size,output_size）那么大，不同之处就在于，此时的中心不在grs.center了而已。
#
# 至此，该问题解决。

# %% [markdown]
# 但是训练的时候，开始没问题，过一会又出现另外一个错误：

# %% [markdown]
# The size of tensor a (204) must match the size of tensor b (200) at non-singleton dimension 3
#
# 具体不知道哪出了问题，但可以看出是唯独不匹配的问题，同时程序给定位到了
#
# p_loss = F.mse_loss(pos_pred, y_pos)
#
# 这里，也就是ggcnn里面计算compute_loss的地方，然后我到这个地方加了几个print

# %%
print(xc.shape)
print(pos_pred.shape)
print(cos_pred.shape)
print(sin_pred.shape)
print(width_pred.shape)
print(y_pos.shape)

# %%
#结果如下：
torch.Size([32, 4, 200, 200])
torch.Size([32, 1, 204, 204])
torch.Size([32, 1, 204, 204])
torch.Size([32, 1, 204, 204])
torch.Size([32, 1, 204, 204])
torch.Size([32, 1, 200, 200])

# %% [markdown]
# 发现是预测出的结果shape不匹配，这就很奇怪，因为我给网络的输入shape一直都没变的， 按理说别管输出结果对不对，shape总不至于出现问题，但是这里就是出现问题了，很奇怪，查了一下资料，有人说是batch_size不能被总的数据个数整除，还有人说是有异常数据等，我觉得我这不是那些原因，试了几次后，问题还真的跟batch_size有关，因为只要我把batch_size设为64,那么最后63的时候就会出错，设为32,那么31的时候就会出错，设为1,那么就运行一次，上来就报错。这就说明问题了，下面把它找出来。
#
# 另外还有一点需要注意，就是，我把output_size设为300的时候就没问题了，设为其他的就不行。（ps，尝试了一下，ggcnn里面把outpust_size设置为200的话也会报这个错误，说明原作者也没解决这个错误）
#
# 目前就这俩疑点。

# %% [markdown]
# 好吧，也没查什么资料，听了一会嵩哥的歌就想明白了怎么回事，这是网络结构的问题，因为网络的输出是由输入和网络参数同时决定的，现在的网络结构能够保证我的输入为300时输出也为300，因为肯定是经过原作者精心设计的，如果换了输入的shape，那么网络的参数就不能保证此刻的输出仍然跟输入保持相同的shape了，至于为什么到batch_size个的时候才会报错，原因也很简单，因为这是随机梯度下降，每个batch才会计算一次损失，不计算损失的时候，是发现不了预测输出的维度和理想输出的维度不匹配的，解决方法有两个：1.手动调整网络参数，使预测输出与理想输出匹配。2.修改gnerate_img里生成映射图的大小，使之与预测输出匹配。
#
# 目前的网络结构如下：

# %%
'''
----------------------------------------------------------------
        Layer (type)               Output Shape         Param #
================================================================
            Conv2d-1         [-1, 32, 100, 100]           2,624
            Conv2d-2           [-1, 16, 50, 50]          12,816
            Conv2d-3            [-1, 8, 25, 25]           1,160
   ConvTranspose2d-4            [-1, 8, 50, 50]             584
   ConvTranspose2d-5         [-1, 16, 100, 100]           3,216
   ConvTranspose2d-6         [-1, 32, 301, 301]          41,504
            Conv2d-7          [-1, 1, 300, 300]             129
            Conv2d-8          [-1, 1, 300, 300]             129
            Conv2d-9          [-1, 1, 300, 300]             129
           Conv2d-10          [-1, 1, 300, 300]             129
================================================================
'''

# %% [markdown]
# 所以，目前为止，只要我们设定输入的shape为（300,300），训练是可以正常进行的。ojbk。完整的训练程序已经集成到了train_main2.py里面
